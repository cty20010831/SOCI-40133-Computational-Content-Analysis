# %% [markdown]
# <a href="https://colab.research.google.com/github/cty20010831/SOCI-40133-Computational-Content-Analysis/blob/main/week%204/4_Word_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 - Exploring Semantic Spaces (Word Embeddings)
# This week, we build on last week's topic modeling techniques by taking a text corpus we have developed, specifying an underlying number of dimensions, and training a model with a neural network auto-encoder (one of Google's word2vec  algorithms) that best describes corpus words in their local linguistic contexts, and exploring their locations in the resulting space to learn about the discursive culture that produced them.
#
# This is our third document representation we have learned: First, we used word counts. Second, we used LDA topic models built around term coocurrence in the same document (i.e., a "bag of words"). Third, documents here are represented as densely indexed locations in dimensions, so that distances between those documents (and words) contain more information, though they require the full vector of dimension loadings (rather than just a few selected topic loadings) to describe. We will explore these spaces to understand complex, semantic relationships between words, index documents with descriptive words, identify the likelihood that a given document would have been produced by a given vector model, and explore how semantic categories can help us understand the cultures that produced them.
#
# Note that most modern natural language processing (NLP) research, at least in computer science, uses word embeddings. This is the foundation of most state-of-the-art models.
#
# Also note that the code in this Notebook can take many minutes or even hours to run. This is the case for most NLP research these days, and it's a good opportunity to start thinking about how to manage high-compute workloads, such as running code on small samples to test it, loading datafiles in [chunks](https://stackoverflow.com/a/25962187), or [multiprocessing](https://en.wikipedia.org/wiki/Multiprocessing).

# %% [markdown]
# ## <font color="red">*Pitch Your Project*</font>
#
# <font color="red">In the three cells immediately following, describe **WHAT** you are planning to analyze for your final project (i.e., texts, contexts and the social game, world and actors you intend to learn about through your analysis) (<200 words), **WHY** you are going to do it (i.e., why would theory and/or the average person benefit from knowing the results of your investigation) (<200 words), and **HOW** you plan to investigate it (i.e., what are the approaches and operations you plan to perform, in sequence, to yield this insight) (<400 words).
#
# # ***What?***
# For now, I have three research questions in mind regarding the influence of funding on psychology research:
#
# 1. How funding influence psychologist' research output (in terms of number of citations)?
# 2. Is there a "trap" of funding in which psychology researchers with funding are increasingly loosing the diversity of the resarch topics they examine?
# 3. What are the variation of the content/research topics of funded pscyhology papers (e.g., in terms of cross-disciplinary collaboration) for different types of funding types/categories?
#
# ## ***Why?***
# The reason why I want to answer these research questions is that I am interested in the effects (and also, perhaps, meaningfulness) of funding in psychology papers. For instance, will the funding leads to more impactful and flourishing research? I think one implication here is that funding agencies can better decide upon what types of research projects (and researchers) they should grant funding on.
#
# ## ***How?***
# <400 words
#
# ## <font color="red">*Pitch Your Sample*</font>
#
# <font color="red">In the cell immediately following, describe the rationale behind your proposed sample design for your final project. What is the social game, social work, or social actors you about whom you are seeking to make inferences? What are its virtues with respect to your research questions? What are its limitations? What are alternatives? What would be a reasonable path to "scale up" your sample for further analysis (i.e., high-profile publication) beyond this class? (<300 words).
#
# ## ***Which (words)?***
# <300 words

# %%
# !pip install -U git+https://github.com/UChicago-Computational-Content-Analysis/lucem_illud.git

# %%
#All these packages need to be installed from pip
import gensim#For word2vec, etc
import requests #For downloading our datasets
import lucem_illud #pip install -U git+https://github.com/UChicago-Computational-Content-Analysis/lucem_illud.git

import numpy as np #For arrays
import pandas as pd #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer
import sklearn.metrics.pairwise #For cosine similarity
import sklearn.manifold #For T-SNE
import sklearn.decomposition #For PCA

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning
# %matplotlib inline

import os #For looking through files
import os.path #For managing file paths

# %% [markdown]
# # Getting our corpora
#
# Instead of downloading our corpora, we have download them in advance; a subset of the [senate press releases](https://github.com/lintool/GrimmerSenatePressReleases) are in `grimmerPressReleases`. We will load them into a DataFrame, but first we need to define a function to convert directories of text files into DataFrames:

# %%
def loadDir(targetDir, category):
    allFileNames = os.listdir(targetDir)
    #We need to make them into usable paths and filter out hidden files
    filePaths = [os.path.join(targetDir, fname) for fname in allFileNames if fname[0] != '.']

    #The dict that will become the DataFrame
    senDict = {
        'category' : [category] * len(filePaths),
        'filePath' : [],
        'text' : [],
    }

    for fPath in filePaths:
        with open(fPath, encoding="ISO-8859-1") as f:
            senDict['text'].append(f.read())
            senDict['filePath'].append(fPath)

    return pd.DataFrame(senDict)

# %%
# Here I mount google drive. I stored all the data in the drive so I can extract data file directly from there. If you don't want to use the drive,
# you can always upload the data to /content/ directly.
# We recommend drive for the larger datasets.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/MACS_60000_Computational Content Analysis')

# %% [markdown]
# Now we can use the function in all the directories in `data/grimmerPressReleases`. If you are on Google Colab, note that rather than downloading GitHub data to your local machine and then uploading it to Drive, you can more quickly `git clone` directly to Colab, such as `!git clone https://github.com/lintool/GrimmerSenatePressReleases.git /drive/MyDrive/`, which then makes your `dataDir = 'drive/MyDrive/grimmerPressReleases/raw'`.

# %%
# !git clone https://github.com/lintool/GrimmerSenatePressReleases.git
# Out:
# Cloning into 'GrimmerSenatePressReleases'...
# remote: Enumerating objects: 72693, done.
# remote: Total 72693 (delta 0), reused 0 (delta 0), pack-reused 72693
# Receiving objects: 100% (72693/72693), 95.17 MiB | 7.84 MiB/s, done.
# Resolving deltas: 100% (2642/2642), done.
# Updating files: 100% (72788/72788), done.

# %%
dataDir = 'GrimmerSenatePressReleases/raw'

senReleasesDF = pd.DataFrame()

for senatorName in [d for d in os.listdir(dataDir) if d[0] != '.']:
    senPath = os.path.join(dataDir, senatorName)
    senReleasesDF = senReleasesDF.append(loadDir(senPath, senatorName), ignore_index = True)

senReleasesDF[:100:10]
# Out:
#    category                                           filePath  \
# 0     Akaka  GrimmerSenatePressReleases/raw/Akaka/10Apr2007...
# 10    Akaka  GrimmerSenatePressReleases/raw/Akaka/10May2007...
# 20    Akaka  GrimmerSenatePressReleases/raw/Akaka/11Jan2007...
# 30    Akaka  GrimmerSenatePressReleases/raw/Akaka/12Apr2005...
# 40    Akaka  GrimmerSenatePressReleases/raw/Akaka/12Jul2006...
# 50    Akaka  GrimmerSenatePressReleases/raw/Akaka/13Feb2006...
# 60    Akaka  GrimmerSenatePressReleases/raw/Akaka/13Mar2006...
# 70    Akaka  GrimmerSenatePressReleases/raw/Akaka/14Dec2007...
# 80    Akaka  GrimmerSenatePressReleases/raw/Akaka/14Nov2007...
# 90    Akaka  GrimmerSenatePressReleases/raw/Akaka/15Feb2007...
#
#                                                  text
# 0   April06,200712:44 AM EDTAP Newsmaker: Akaka se...
# 10  WASHINGTON - U.S. Senators Daniel K. Inouye an...
# 20  Washington, D.C. - U.S. Senators Daniel K. Aka...
# 30  Washington, D.C. - U.S. Senator Daniel K. Akak...
# 40  Washington, D.C. - Senator Daniel K. Akaka (D-...
# 50  Washington, D.C. -- Today the American Bar Ass...
# 60  Washington, D.C. - Senator Daniel K. Akaka mad...
# 70  Washington, DC - U.S. Senators Daniel K. Akaka...
# 80  Washington, D.C. - U.S. Senator Daniel K. Akak...
# 90  Washington, DC - U.S. Senator Daniel K. Akaka ...

# %% [markdown]
# Word2Vec needs to retain the sentence structure so as to capture a "continuous bag of words (CBOW)" and all of the skip-grams within a word window. The algorithm tries to preserve the distances induced by one of these two local structures. This is very different from clustering and LDA topic modeling which extract unordered words alone.
#
# When we normalize here, we don't use the lematized form of the word because we might lose information. Note the paramter in the normalize tokens function.

# %%
#Apply our functions, notice each row is a list of lists now
from tqdm import tqdm
tqdm.pandas()

senReleasesDF['tokenized_sents'] = senReleasesDF['text'].progress_apply(lambda x: [lucem_illud.word_tokenize(s) for s in lucem_illud.sent_tokenize(x)])
senReleasesDF['normalized_sents'] = senReleasesDF['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, lemma=False) for s in x])
# With the latest spacy versions, you may get warnings with the following line of code. See the discussion here: https://github.com/allenai/allennlp/issues/5036
# senReleasesDF['normalized_sents'] = senReleasesDF['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s) for s in x])

senReleasesDF[:100:10]
# Out:
#   0%|          | 0/72785 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# 100%|██████████| 72785/72785 [3:42:41<00:00,  5.45it/s]
#    category                                           filePath  \
# 0     Akaka  GrimmerSenatePressReleases/raw/Akaka/10Apr2007...
# 10    Akaka  GrimmerSenatePressReleases/raw/Akaka/10May2007...
# 20    Akaka  GrimmerSenatePressReleases/raw/Akaka/11Jan2007...
# 30    Akaka  GrimmerSenatePressReleases/raw/Akaka/12Apr2005...
# 40    Akaka  GrimmerSenatePressReleases/raw/Akaka/12Jul2006...
# 50    Akaka  GrimmerSenatePressReleases/raw/Akaka/13Feb2006...
# 60    Akaka  GrimmerSenatePressReleases/raw/Akaka/13Mar2006...
# 70    Akaka  GrimmerSenatePressReleases/raw/Akaka/14Dec2007...
# 80    Akaka  GrimmerSenatePressReleases/raw/Akaka/14Nov2007...
# 90    Akaka  GrimmerSenatePressReleases/raw/Akaka/15Feb2007...
#
#                                                  text  \
# 0   April06,200712:44 AM EDTAP Newsmaker: Akaka se...
# 10  WASHINGTON - U.S. Senators Daniel K. Inouye an...
# 20  Washington, D.C. - U.S. Senators Daniel K. Aka...
# 30  Washington, D.C. - U.S. Senator Daniel K. Akak...
# 40  Washington, D.C. - Senator Daniel K. Akaka (D-...
# 50  Washington, D.C. -- Today the American Bar Ass...
# 60  Washington, D.C. - Senator Daniel K. Akaka mad...
# 70  Washington, DC - U.S. Senators Daniel K. Akaka...
# 80  Washington, D.C. - U.S. Senator Daniel K. Akak...
# 90  Washington, DC - U.S. Senator Daniel K. Akaka ...
#
#                                       tokenized_sents  \
# 0   [[April06,200712:44, AM, EDTAP, Newsmaker, Aka...
# 10  [[WASHINGTON, U.S., Senators, Daniel, K., Inou...
# 20  [[Washington, D.C., U.S., Senators, Daniel, K....
# 30  [[Washington, D.C., U.S., Senator, Daniel, K.,...
# 40  [[Washington, D.C., Senator, Daniel, K., Akaka...
# 50  [[Washington, D.C., Today, the, American, Bar,...
# 60  [[Washington, D.C., Senator, Daniel, K., Akaka...
# 70  [[Washington, DC, U.S., Senators, Daniel, K., ...
# 80  [[Washington, D.C., U.S., Senator, Daniel, K.,...
# 90  [[Washington, DC, U.S., Senator, Daniel, K., A...
#
#                                      normalized_sents
# 0   [[april06,200712:44, edtap, newsmaker, akaka, ...
# 10  [[washington, u.s, senators, daniel, k., inouy...
# 20  [[washington, d.c, u.s, senators, daniel, k., ...
# 30  [[washington, d.c, u.s, senator, daniel, k., a...
# 40  [[washington, d.c, senator, daniel, k., akaka,...
# 50  [[washington, d.c, today, american, bar, assoc...
# 60  [[washington, d.c, senator, daniel, k., akaka,...
# 70  [[washington, dc, u.s, senators, daniel, k., a...
# 80  [[washington, d.c, u.s, senator, daniel, k., a...
# 90  [[washington, dc, u.s, senator, daniel, k., ak...

# %%
# Save the normalized dataframe (to easily load it in Google Colab next time)
# senReleasesDF.to_json('senReleasesDF.json', orient='records', lines=True)
senReleasesDF = pd.read_json('senReleasesDF.json', orient='records', lines=True)

# %% [markdown]
# # Word2Vec
#
# We will be using the gensim implementation of [Word2Vec](https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec). Note that newer versions of gensim have different syntax, but if you're using a newer version, you should see informative error messages (e.g., replace `senReleasesW2V['president'][:10]` with `senReleasesW2V['president'].wv[:10]`). The following lines should work out-of-the-box on Google Colab.
#
# To load our data our data we give all the sentences to the trainer:

# %%
# The sg=0 argument indicates that we don't want to use "skipgram" but instead "CBOW"
senReleasesW2V = gensim.models.word2vec.Word2Vec(senReleasesDF['normalized_sents'].sum(), sg=0)

# %% [markdown]
# Inside the word2vec object, each word has a vector. To access the vector directly, use the square braces (`__getitem__`) method:

# %%
senReleasesW2V.wv['president'][:10] #Shortening because it's very large
# Out:
# array([ 2.107119  ,  1.9083965 ,  0.09141442, -0.08277788,  1.12501   ,
#         0.69899553,  0.3488399 , -0.9395853 ,  0.5309741 , -1.9970436 ],
#       dtype=float32)

# %% [markdown]
# If you want the full matrix, `syn0` stores all the vectors:

# %%
senReleasesW2V.wv.vectors
# Out:
# array([[-9.7484958e-01, -1.0195228e+00, -1.0974851e+00, ...,
#         -8.3216196e-01, -1.1773034e+00, -4.6624956e+00],
#        [-1.6651366e+00, -1.1696991e+00,  7.6749039e-01, ...,
#         -1.2061957e+00, -3.4028184e-01, -9.1789448e-01],
#        [-6.8104494e-01, -4.1169912e-01,  6.9060051e-01, ...,
#          2.6365604e+00,  6.2053508e-01, -1.3226361e+00],
#        ...,
#        [ 1.1499944e-01,  4.3493421e-03,  7.5733364e-02, ...,
#         -5.0981292e-03, -8.7804701e-03,  1.8874463e-02],
#        [-2.0151110e-02,  3.5423394e-02,  2.8122211e-02, ...,
#         -1.7514426e-02,  7.1745135e-02, -2.3131287e-03],
#        [-9.3660122e-03, -2.9090866e-02, -1.5744982e-02, ...,
#         -6.6469923e-02,  7.9150066e-02,  4.2281255e-02]], dtype=float32)

# %% [markdown]
# Then, `index2word` lets you translate from the matrix to words:

# %%
senReleasesW2V.wv.index_to_key[10]
# Out:
# 'federal'

# %% [markdown]
# Now we can look at a few things that come from the word vectors. The first is to find similar vectors (cosine similarity):

# %%
senReleasesW2V.wv.most_similar('federal')
# Out:
# [('local', 0.5244466662406921),
#  ('administer', 0.46907925605773926),
#  ('enforcement', 0.45016613602638245),
#  ('jurisdictions', 0.4401894807815552),
#  ('localities', 0.4325554668903351),
#  ('addition', 0.420999675989151),
#  ('matching', 0.4208633601665497),
#  ('additional', 0.41904619336128235),
#  ('state', 0.41830721497535706),
#  ('federally', 0.4140814244747162)]

# %%
senReleasesW2V.wv.most_similar('war')
# Out:
# [('afghanistan', 0.6359058022499084),
#  ('wars', 0.6303964853286743),
#  ('strife', 0.6170836091041565),
#  ('invasion', 0.5816400051116943),
#  ('disobedience', 0.550549328327179),
#  ('quagmire', 0.5433782935142517),
#  ('conflict', 0.5351376533508301),
#  ('battle', 0.5298022031784058),
#  ('troops', 0.5142112970352173),
#  ('blooded', 0.513683021068573)]

# %% [markdown]
# Find which word least matches the others within a word set (cosine similarity):

# %%
senReleasesW2V.wv.doesnt_match(['administration', 'administrations', 'presidents', 'president', 'washington'])
# Out:
# 'washington'

# %% [markdown]
# Find which word best matches the result of a semantic *equation* (here, we seek the words whose vectors best fit the missing entry from the equation: **X + Y - Z = _**.

# %%
senReleasesW2V.wv.most_similar(positive=['clinton', 'republican'], negative = ['democrat'])
# Out:
# [('schumer', 0.574946403503418),
#  ('clintons', 0.5489715337753296),
#  ('mikulski', 0.5239667296409607),
#  ('bayh', 0.506996750831604),
#  ('frist', 0.5020976662635803),
#  ('santorum', 0.4936032295227051),
#  ('bidens', 0.4675787389278412),
#  ('sununu', 0.4652703106403351),
#  ('voinovich', 0.4631951153278351),
#  ('allen', 0.45878180861473083)]

# %% [markdown]
# Here we see that **Clinton + Republican - Democrat = Bush**. In other words, in this dataset, **Clinton** is to **Democrat** as **Bush** is to **Republican**. Whoah!

# %% [markdown]
# We can also save the vectors for later use:

# %%
senReleasesW2V.save("senpressreleasesWORD2Vec")

# %% [markdown]
# We can also use dimension reduction to visulize the vectors. We will start by selecting a subset we want to plot. Let's look at the top words from the set:

# %%
numWords = 50
targetWords = senReleasesW2V.wv.index_to_key[:numWords]

# %% [markdown]
# We can then extract their vectors and create our own smaller matrix that preserved the distances from the original:

# %%
wordsSubMatrix = []
for word in targetWords:
    wordsSubMatrix.append(senReleasesW2V.wv[word])
wordsSubMatrix = np.array(wordsSubMatrix)
wordsSubMatrix
# Out:
# array([[-0.9748496 , -1.0195228 , -1.0974851 , ..., -0.83216196,
#         -1.1773034 , -4.6624956 ],
#        [-1.6651366 , -1.1696991 ,  0.7674904 , ..., -1.2061957 ,
#         -0.34028184, -0.9178945 ],
#        [-0.68104494, -0.41169912,  0.6906005 , ...,  2.6365604 ,
#          0.6205351 , -1.3226361 ],
#        ...,
#        [-2.9382343 , -0.4316987 ,  2.6232147 , ...,  4.305185  ,
#         -0.69418186, -2.008852  ],
#        [-1.0980917 ,  0.39748073, -2.651917  , ...,  2.121867  ,
#         -5.3302064 , -1.3445439 ],
#        [-3.4045742 , -2.8860135 , -1.2579249 , ...,  1.5218751 ,
#          0.91696835, -1.5501513 ]], dtype=float32)

# %% [markdown]
# Then we can use PCA to reduce the dimesions (e.g., to 50), and T-SNE to project them down to the two we will visualize. We note that this is nondeterministic process, and so you can repeat and achieve alternative projectsions/visualizations of the words:

# %%
pcaWords = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_data = pcaWords.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWords = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_data)

# %% [markdown]
# We now can plot the points

# %%
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords[:, 0], tsneWords[:, 1], alpha = 0)#Making the points invisible
for i, word in enumerate(targetWords):
    ax.annotate(word, (tsneWords[:, 0][i],tsneWords[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# My visualization above puts ``said`` next to ``congress`` and ``bill`` near ``act``. ``health`` is beside ``care`` and ``national`` abuts ``security``.

# %% [markdown]
# ## Adding more context - FastText
#
# Since the original word2vec paper, there have followed a slew of word embedding related methods which innovate and build on them in many ways. One popular extension is FastText ([Bojanowski et al. 2017](https://arxiv.org/abs/1607.04606)), which uses sub-words to generate its vectors. Using subwords means that it is powerful in dealing with unknown words and sparse languages that otherwise have a rich morphological structure. These sub-words are incorporated into the previously skipgram and CBOW methods. For example, if the word is “which”, it is represented as the word itself along with a bag of constituent n-grams. If n=3, the representation looks like <wh, whi, hic, ich, ch>, and we learn a representation for each of these constituents, with the word “which” taking on the average value of these constituents.
#
# FastText can be used either via Gensim or the official package, and primarily has two functions - word representations, and text classification (Joulin et al. 2017). See below for code using the FastText package for playing with word representations, taken from their word representations tutorial (https://fasttext.cc/docs/en/unsupervised-tutorial.html).

# %%
! pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.23.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199773 sha256=e041c4eafbbc92a8fb4084e113676e29903c4bb811ddc6ac5196dac63a1372ae
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.11.1

# %% [markdown]
# ### Representations with FastText
#
# We will follow the instructions in the FastText tutorial to prepare our data, (Wikipedia). You can either follow the instructions on the page for setting the data, or download/copy it to drive it from this [Google Drive link](https://drive.google.com/file/d/12T3nNzf0a7tdhm1lVyfz9Ix9XVITFMCP/view?usp=sharing).
#
# In this example, we will be training a model - it is also possible to download and use the many pre-trained models.

# %%
import fasttext

# %%
# Replace with the path for where you have placed the 'fil9' file.
file_address = "fil9"

# %%
model = fasttext.train_unsupervised(file_address, minCount=200, epoch=1)

# %% [markdown]
# While FastText is running, the progress and estimated time to completion is shown on your screen. Once the training finishes, the model variable contains information on the trained model, which you can use for querying:

# %%
model.words

# %% [markdown]
# It returns all words in the vocabulary, sorted by decreasing frequency. We can get the word vector by:

# %%
model.get_word_vector("the")
# Out:
# array([ 1.01263069e-01, -5.90192489e-02,  1.61868244e-01, -1.01701789e-01,
#         2.11401746e-01,  3.44076864e-02,  1.06779106e-01, -7.01764673e-02,
#        -2.77115434e-01, -3.33278567e-01, -2.25600272e-01,  2.84197815e-02,
#         4.64334451e-02, -3.16535458e-02,  1.81303080e-02,  4.28940691e-02,
#         1.87967479e-01, -2.95054838e-02,  7.59627223e-02,  2.25423761e-02,
#         1.01923592e-01, -3.57791893e-02,  1.26660556e-01, -6.02674000e-02,
#         7.77557120e-02,  2.25575492e-01,  3.91170114e-01,  2.25593746e-01,
#        -2.84654528e-01, -9.91142765e-02,  6.44938052e-02,  2.01031938e-01,
#        -6.81440681e-02, -1.06424704e-01,  4.65644971e-02,  1.19772151e-01,
#        -6.29343688e-02,  3.63371581e-01,  4.77561578e-02,  6.11040592e-02,
#        -8.36888999e-02, -4.58102636e-02, -1.21765435e-01,  9.46124494e-02,
#         2.85717428e-01, -1.05698608e-01,  4.03688736e-02,  1.54146299e-01,
#        -1.79450721e-01, -9.32932720e-02,  7.56328460e-03, -1.15344204e-01,
#         1.28116474e-01,  2.27502431e-04,  1.04870088e-01,  3.57625750e-03,
#         6.11933470e-02,  3.44021440e-01,  1.83814596e-02,  1.10985659e-01,
#        -7.97396079e-02,  4.45164815e-02,  1.33992359e-01, -1.16355089e-03,
#        -2.72079632e-02,  1.76343113e-01,  6.00682795e-02, -1.68184772e-01,
#         7.49714598e-02,  5.78158855e-01,  8.47205818e-02,  4.11786214e-02,
#        -3.60001504e-01,  2.00931177e-01, -3.03339422e-01, -1.09124994e-02,
#         2.24217206e-01, -3.96743529e-02,  3.62054817e-03,  2.04394553e-02,
#         4.42883838e-03,  1.92641951e-02,  1.32325932e-01,  1.35405734e-01,
#        -1.37650371e-01, -1.33473784e-01, -6.05072156e-02, -2.12125108e-02,
#        -1.14011712e-01, -7.62262344e-02,  1.37803257e-01, -5.73889306e-03,
#         6.32500798e-02,  6.79576173e-02, -3.08129881e-02,  4.96762164e-04,
#        -2.31538475e-01,  1.42571017e-01, -2.38388479e-01, -5.33212051e-02],
#       dtype=float32)

# %%
model.save_model("fil9.bin")

# %%
# when we want to use the model again
model = fasttext.load_model("fil9.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# Let's now print some vectors.

# %%
[model.get_word_vector(x) for x in ["asparagus", "pidgey", "yellow"]]
# Out:
# [array([-0.14006662, -0.07485355,  0.319586  , -0.04093548,  0.09198429,
#          0.1261278 , -0.03269082, -0.11055066,  0.04655714, -0.1326036 ,
#         -0.04546691, -0.25087675,  0.18515807,  0.14625898, -0.06811476,
#          0.05070682,  0.17836626,  0.04091097, -0.08842913,  0.151132  ,
#          0.06338568, -0.17596854, -0.07060655,  0.1902626 , -0.0789043 ,
#          0.03498681,  0.43267778,  0.12663811, -0.14121874, -0.0656484 ,
#          0.05628384,  0.25708377,  0.20422208, -0.03867839,  0.10115422,
#         -0.02700523, -0.11787999,  0.32505086, -0.05171636,  0.136551  ,
#         -0.17223425,  0.25701734, -0.22905089, -0.04056008,  0.0833502 ,
#          0.15513909,  0.37595323, -0.04926715, -0.15345646,  0.21379124,
#         -0.18380232,  0.01716743, -0.1489495 , -0.15657601,  0.26150805,
#         -0.14652215,  0.04858861,  0.3603034 , -0.06512161,  0.16244695,
#          0.00835189, -0.01089688,  0.4704638 , -0.09488831, -0.06462533,
#          0.3277814 ,  0.16953354, -0.04525212, -0.0394    ,  0.5478661 ,
#          0.10780362, -0.01318696, -0.00102221,  0.21053123, -0.5303099 ,
#          0.06886761, -0.01543016, -0.02558694,  0.00879508,  0.11968584,
#         -0.01695436,  0.23387313,  0.10074896,  0.13705987,  0.01587402,
#          0.01900588,  0.01900471,  0.02872453, -0.2695456 ,  0.13514474,
#          0.31871247, -0.24489954,  0.2438422 ,  0.08567275, -0.09061009,
#         -0.1802018 , -0.05237166,  0.13741867, -0.32155406, -0.02756416],
#        dtype=float32),
#  array([ 0.12573254, -0.00287866, -0.10282707, -0.06418545,  0.15428016,
#          0.00832207, -0.07165326, -0.10438471, -0.25355953, -0.05804789,
#         -0.18828379, -0.06369569, -0.11376408, -0.01163321,  0.10519059,
#          0.01673424,  0.3520933 , -0.2860257 , -0.03483367,  0.00689866,
#          0.3495222 ,  0.13261503, -0.12178951,  0.11032788,  0.03255888,
#          0.15444058,  0.13478099, -0.1300374 , -0.03913837, -0.11096004,
#          0.028783  ,  0.27570263, -0.23104048, -0.02493712,  0.10418323,
#         -0.0828538 , -0.12237769,  0.05122918,  0.23855022,  0.10430776,
#         -0.0482051 ,  0.33881694,  0.0024301 ,  0.382367  ,  0.00300065,
#          0.09421943,  0.1756864 ,  0.19956006,  0.08071963, -0.09258721,
#         -0.08277605, -0.03202801, -0.07885891, -0.01648235,  0.11536031,
#         -0.20490268,  0.0255079 ,  0.17211069,  0.02026618,  0.07545197,
#          0.17855325,  0.11051659,  0.06829532,  0.03424916,  0.19116424,
#         -0.03844685, -0.10852261,  0.10302328, -0.01626025,  0.3970409 ,
#          0.02761037,  0.16461731, -0.06485455,  0.08209174, -0.31960002,
#         -0.07777752,  0.01427165, -0.00662784, -0.0471561 ,  0.21585706,
#          0.03691593,  0.15404592, -0.12855305,  0.02320098, -0.14412294,
#         -0.22378707, -0.19954503,  0.11550123, -0.19607046,  0.1282491 ,
#          0.13486122, -0.44061893,  0.04384957,  0.031729  ,  0.19641496,
#          0.09153392, -0.23380113, -0.08791954, -0.10430647,  0.00308775],
#        dtype=float32),
#  array([-0.4259764 , -0.29276532,  0.5273134 ,  0.03355831,  0.2913913 ,
#         -0.14058344, -0.02668593,  0.14763823,  0.05386255, -0.14300065,
#          0.02082091, -0.43478644,  0.00960877,  0.9598713 ,  0.41798714,
#          0.1892765 ,  0.2323183 , -0.05382464, -0.10154898, -0.3886392 ,
#          0.9859782 ,  0.10194101, -0.20625047, -0.06464926,  0.0062704 ,
#          0.10538488,  0.18445967, -0.10531045,  0.33570993, -0.01739975,
#          0.31214464,  0.19119969, -0.02489077, -0.10772837, -0.28551614,
#         -0.34163615, -0.34152415, -0.12842992,  0.07896135,  0.36435345,
#          0.5372824 ,  0.12265488,  0.19569504,  0.4422578 , -0.10776743,
#         -0.29176837,  0.05743027,  0.33558914,  0.02231786, -0.07293915,
#         -0.21863236, -0.1292092 , -0.35023144, -0.33505988,  0.5146573 ,
#         -0.06539424,  0.436771  ,  0.4882916 , -0.11236592,  0.126161  ,
#         -0.00590041,  0.49175555, -0.16628343, -0.2519955 ,  0.21791843,
#          0.23121588,  0.09160879, -0.11410126,  0.12577093,  0.56529087,
#          0.07731725, -0.31338   , -0.77196294,  0.20719668, -0.1068586 ,
#          0.01149709,  0.01647074, -0.41346213,  0.42691955, -0.05102881,
#          0.15621884,  0.24498595, -0.39100727, -0.26140597,  0.17646717,
#          0.00954813, -0.47050804,  0.14953737, -0.44752693,  0.40070078,
#          0.01759284, -0.21562947, -0.1283689 , -0.3372605 , -0.3129569 ,
#         -0.08722878, -0.3916072 , -0.07832672, -0.38784972, -0.2931354 ],
#        dtype=float32)]

# %% [markdown]
# A nice feature is that you can also query for words that did not appear in your data! Indeed words are represented by the sum of their substrings. As long as the unknown word is made of known substrings, there is a representation of it!
#
# As an example let's try with a misspelled word:

# %%
model.get_word_vector("enviroment")
# Out:
# array([-2.70548295e-02,  1.50540456e-01,  2.53648639e-01, -4.23338339e-02,
#         1.38390139e-01,  1.23571225e-01, -3.33544403e-01, -3.00642520e-01,
#        -5.74875437e-02,  4.31564808e-01, -2.16350675e-01, -1.72045216e-01,
#         6.48741424e-02,  4.55947854e-02,  1.11958481e-01, -1.84667960e-01,
#         3.20180207e-01, -2.58245885e-01, -5.46172746e-02, -1.11285992e-01,
#         2.84395278e-01, -2.85696507e-01, -7.29190707e-02,  1.13132909e-01,
#         1.05610386e-01,  2.34497786e-01,  4.10215378e-01,  2.38320827e-01,
#        -1.79288089e-01, -5.25667548e-01,  1.53210200e-02,  1.14100046e-01,
#         1.30865082e-01, -4.06445339e-02,  6.67985082e-02, -4.82941747e-01,
#        -1.17705710e-01,  1.97724909e-01,  2.43855476e-01,  2.99321171e-02,
#        -2.99975365e-01,  2.00883836e-01, -1.07507303e-01,  3.99979770e-01,
#         2.07314998e-01,  5.43931544e-01, -9.83017087e-02,  2.69692481e-01,
#        -2.01667085e-01, -1.80381555e-02,  1.18486591e-01,  1.65626518e-02,
#         1.53593928e-01, -3.00374955e-01,  2.93128610e-01, -8.53997618e-02,
#         2.03572944e-01,  2.51544625e-01,  1.62613213e-01,  4.10218388e-01,
#        -2.56114145e-04,  7.24920109e-02,  4.59066272e-01, -9.82580706e-02,
#         1.14748560e-01,  6.27558902e-02,  2.31533453e-01, -6.09344542e-02,
#        -2.10794196e-01,  4.43243712e-01,  1.05104014e-01,  2.93489277e-01,
#        -4.03621309e-02,  4.13190633e-01,  3.81642058e-02,  2.87195832e-01,
#        -1.41064331e-01, -9.57780108e-02,  1.29738584e-01,  1.43575305e-02,
#         1.56115860e-01,  3.75275582e-01,  1.72618583e-01,  6.30356073e-02,
#        -1.49243683e-01, -1.67699710e-01,  3.44313122e-02, -1.09144755e-01,
#        -7.63159692e-02,  2.58805543e-01,  2.35394519e-02, -2.72366315e-01,
#         2.96085119e-01,  2.46852934e-01, -5.80196120e-02,  1.45772129e-01,
#        -2.75893390e-01, -3.81554663e-02, -3.17114621e-01,  1.05040841e-01],
#       dtype=float32)

# %% [markdown]
# ## <font color="red">*Exercise 1*</font>
#
# <font color="red">Construct cells immediately below this that embed documents related to your final project using at least two different specification of `word2vec` and/or `fasttext`, and visualize them each with two separate visualization layout specifications (e.g., TSNE, PCA). Then interrogate critical word vectors within your corpus in terms of the most similar words, analogies, and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the semantic organization of words in your corpora? Which estimation and visualization specification generate the most insight and appear the most robustly supported and why?
#
# <font color="red">***Stretch***: Explore different vector calculations beyond addition and subtraction, such as multiplication, division or some other function. What does this exploration reveal about the semantic structure of your corpus?

# %%
import getpass
import time
import requests
import random
import pandas

# %%
api_key = getpass.getpass("Enter your API key: ")
headers = {"x-api-key": api_key}
# Out:
# Enter your API key: ··········

# %%
# Define the function to scrape abstract
def scrape_abstract_updated(fieldsOfStudy, year, limit_per_field=600,
                            url='https://api.semanticscholar.org/graph/v1/paper/search'):

    headers = {"x-api-key": "KOyXiGdu4t38zFJFFyuKF5jQGBGdxCSfDICseepg"}

    all_data = []

    # Start with no offset
    offset = 0
    total_papers = 0

    while total_papers < limit_per_field:
        query_params = {
            'year': year,
            'query': fieldsOfStudy,
            'fields': 'title,authors,abstract',
            'limit': 100,  # This is typically the max the API allows per request
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=query_params)

        if response.status_code == 200:
            papers = response.json().get('data', [])

            # Break the loop if no papers are returned
            if not papers:
                break

            for paper in papers:
                title = paper.get('title')
                author = paper.get('authors')
                abstract = paper.get('abstract')

                if not title or not author or not abstract:
                    continue

                author_names = ', '.join([a['name'] for a in author])

                all_data.append({
                    "Year": year,
                    "FieldOfStudy": fieldsOfStudy,
                    "Title": title,
                    "Author": author_names,
                    "Abstract": abstract})

                total_papers += 1

                # Break the loop if we have reached the limit
                if total_papers >= limit_per_field:
                    break

        else:
            print(f"Request failed with status code {response.status_code}")
            break

        # Increase the offset for the next loop iteration
        offset += len(papers)

        # Sleep to respect rate limits
        sleep_time = random.randint(1,3)
        time.sleep(sleep_time)

    df = pandas.DataFrame(all_data)

    return df

# %%
# Scrape psychology abstract from 2003 to 2023
fieldsOfStudy = "Psychology"

all_years_data = []

for year in range(2003, 2024):
    df_year = scrape_abstract_updated(fieldsOfStudy, year)
    all_years_data.append(df_year)

# Combine all dataframes
psychology_corpus = pandas.concat(all_years_data, ignore_index=True)

# Sort the final dataframe by year
psychology_corpus = psychology_corpus.sort_values(by='Year').reset_index(drop=True)

psychology_corpus
# Out:
#        Year FieldOfStudy                                              Title  \
# 0      2003   Psychology  Maps of Bounded Rationality: Psychology for Be...
# 1      2003   Psychology  DSM-Oriented and Empirically Based Approaches ...
# 2      2003   Psychology  Does father absence place daughters at special...
# 3      2003   Psychology                         The Psychology of the Body
# 4      2003   Psychology  Validation of the Female Sexual Function Index...
# ...     ...          ...                                                ...
# 12595  2023   Psychology  Kin relationality and ecological belonging: a ...
# 12596  2023   Psychology  Comments on the articles dealing with individu...
# 12597  2023   Psychology  Deviant behavior of law enforcement officers: ...
# 12598  2023   Psychology  Using energy psychology to remediate emotional...
# 12599  2023   Psychology  Curious about threats: Morbid curiosity and in...
#
#                                                   Author  \
# 0                                            D. Kahneman
# 1                  T. Achenbach, L. Dumenci, L. Rescorla
# 2      B. Ellis, J. Bates, K. Dodge, D. Fergusson, L....
# 3                       E. Greene, Barbara Goodrich-Dunn
# 4                                              C. Meston
# ...                                                  ...
# 12595                         Yuria Celidwen, D. Keltner
# 12596                                     J. P. Campbell
# 12597                                      M.N. Bochkova
# 12598                                    David Feinstein
# 12599           Coltan Scrivner, Joseph M. Stubbersfield
#
#                                                 Abstract
# 0      The work cited by the Nobel committee was done...
# 1      Department of Psychology, Bryn Mawr College Se...
# 2      The impact of father absence on early sexual a...
# 3      Section I: The Body Organizes Experience1. The...
# 4      Department of Psychology, University of Texas ...
# ...                                                  ...
# 12595  In this article, we consider prosociality thro...
# 12596  ABSTRACT Individual performance criterion meas...
# 12597  Introduction. Modern Russian studies devoted t...
# 12598  Adverse childhood experiences (ACEs) are poten...
# 12599  Conspiracy theories allege secret plots betwee...
#
# [12600 rows x 5 columns]

# %%
# Save the psychology abstract corpus to a json file
psychology_corpus.to_json('psychology_corpus.json', orient='records', lines=True)
# psychology_corpus = pd.read_json('psychology_corpus.json', orient='records', lines=True)

# %%
# Normalize the sentences
from tqdm import tqdm
tqdm.pandas()

psychology_corpus['tokenized_sents'] = psychology_corpus['Abstract'].progress_apply(lambda x: [lucem_illud.word_tokenize(s) for s in lucem_illud.sent_tokenize(x)])
psychology_corpus['normalized_sents'] = psychology_corpus['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s, lemma=False) for s in x])
# Out:
#   0%|          | 0/12600 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# 100%|██████████| 12600/12600 [18:52<00:00, 11.12it/s]

# %% [markdown]
# First, use `word2vec`:

# %%
# Here I use "skipgram" for word2vec
psychology_corpus_W2V = gensim.models.word2vec.Word2Vec(psychology_corpus['normalized_sents'].sum())

# %%
# Save the vector for later use
psychology_corpus_W2V.save("psychology_corpus_WORD2Vec")

# %%
# Randomly pick 60 words for visualization on a 2D plane
numWords = 40

random.seed(433)
targetWords_psychology_corpus = random.sample(psychology_corpus_W2V.wv.index_to_key, numWords)

wordsSubMatrix_psychology_corpus = []
for word in targetWords_psychology_corpus:
    wordsSubMatrix_psychology_corpus.append(psychology_corpus_W2V.wv[word])
wordsSubMatrix_psychology_corpus = np.array(wordsSubMatrix_psychology_corpus)

# %% [markdown]
# First, use PCA to do dimension reduction:

# %%
pcaWords_psychology_corpus = sklearn.decomposition.PCA(n_components = 2).fit(wordsSubMatrix_psychology_corpus)
reducedPCA_data_psychology_corpus = pcaWords.transform(wordsSubMatrix_psychology_corpus)

# %%
# Visualize
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(reducedPCA_data_psychology_corpus[:, 0], reducedPCA_data_psychology_corpus[:, 1], alpha = 0)#Making the points invisible
for i, word in enumerate(targetWords_psychology_corpus):
    ax.annotate(word, (reducedPCA_data_psychology_corpus[:, 0][i], reducedPCA_data_psychology_corpus[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Then, use TSNE to do dimension reduction:

# %%
tsne = sklearn.manifold.TSNE(n_components = 2, perplexity=30, learning_rate=200)
tsneWords_psychology_corpus = tsne.fit_transform(wordsSubMatrix_psychology_corpus)

# %%
# Visualize
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords_psychology_corpus[:, 0], tsneWords_psychology_corpus[:, 1], alpha = 0)#Making the points invisible
for i, word in enumerate(targetWords_psychology_corpus):
    ax.annotate(word, (tsneWords_psychology_corpus[:, 0][i], tsneWords_psychology_corpus[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Here, I will interrogate critical word vectors within the corpus for `word2vec`:

# %%
target_words = ["cognitive", "memory", "disorder", "attention", "social", "developmental"]

# %%
# Find simialr words
similar_words_w2v = {word: psychology_corpus_W2V.wv.most_similar(word, topn=10) for word in target_words}
similar_words_w2v
# Out:
# {'cognitive': [('behavioural', 0.6955602169036865),
#   ('developmental', 0.6781790256500244),
#   ('intelligence', 0.647026002407074),
#   ('perceptual', 0.6443270444869995),
#   ('behavioral', 0.6441057920455933),
#   ('neuroscience', 0.6342000365257263),
#   ('music', 0.6275234818458557),
#   ('biological', 0.6260868310928345),
#   ('brain', 0.6260207295417786),
#   ('computational', 0.6245361566543579)],
#  'memory': [('visual', 0.7985039949417114),
#   ('perceptual', 0.7900239825248718),
#   ('speech', 0.762784481048584),
#   ('autobiographical', 0.7489993572235107),
#   ('episodic', 0.7465431690216064),
#   ('perception', 0.7452394962310791),
#   ('spatial', 0.7373834252357483),
#   ('comprehension', 0.7274139523506165),
#   ('retrieval', 0.7216001152992249),
#   ('sensory', 0.7129485607147217)],
#  'disorder': [('disorders', 0.9149060249328613),
#   ('alcoholism', 0.9057700634002686),
#   ('eating', 0.8715305328369141),
#   ('disease', 0.8643463850021362),
#   ('acute', 0.8537260293960571),
#   ('pain', 0.8536244630813599),
#   ('chronic', 0.8502491116523743),
#   ('diseases', 0.8487709164619446),
#   ('abuse', 0.8445944786071777),
#   ('depression', 0.8292785882949829)],
#  'attention': [('paid', 0.8328852653503418),
#   ('little', 0.758410632610321),
#   ('attracted', 0.7110460996627808),
#   ('pay', 0.7097377181053162),
#   ('considerable', 0.7068702578544617),
#   ('paying', 0.6997194886207581),
#   ('particular', 0.6659746766090393),
#   ('increasing', 0.6392015218734741),
#   ('received', 0.6383410096168518),
#   ('interest', 0.6378889679908752)],
#  'social': [('political', 0.623219907283783),
#   ('sociocultural', 0.555684506893158),
#   ('politics', 0.5423676371574402),
#   ('criminal', 0.5403887629508972),
#   ('economic', 0.5346375107765198),
#   ('socio', 0.5314165949821472),
#   ('procedural', 0.5287470817565918),
#   ('behavioural', 0.5091872215270996),
#   ('neoliberal', 0.5086701512336731),
#   ('interconnections', 0.5080529451370239)],
#  'developmental': [('psychopathology', 0.7773257493972778),
#   ('biological', 0.7293607592582703),
#   ('biology', 0.7187584638595581),
#   ('ecology', 0.7174749970436096),
#   ('evolutionary', 0.7142279744148254),
#   ('lifespan', 0.7130650281906128),
#   ('anthropology', 0.6911787390708923),
#   ('behavioural', 0.688051164150238),
#   ('sociocultural', 0.687423050403595),
#   ('neuroscience', 0.6852107048034668)]}

# %%
# Find word analogy
print(psychology_corpus_W2V.wv.most_similar(positive=['disorder', 'developmental'], negative=['mental'], topn=1))
print(psychology_corpus_W2V.wv.most_similar(positive=['ability', 'social'], negative=['cognitive'], topn=1))
# Out:
# [('psychopathology', 0.689023494720459)]
# [('motivations', 0.5904983282089233)]

# %% [markdown]
# Then, I will try `fasttext`:

# %%
# Convert the normalized sentence of Abstract into a txt file
sentences = [' '.join(sentence) for sentence_list in psychology_corpus['normalized_sents'] for sentence in sentence_list]

# Write the sentences to a text file, each sentence on a new line
with open('psychology_corpus_sentences.txt', 'w') as file:
    for sentence in sentences:
        file.write(sentence + '\n')

# %%
# Train the model
model = fasttext.train_unsupervised('psychology_corpus_sentences.txt', model='cbow')

# %%
# Randomly extract a sample of 40 words from it
random.seed(42)
targetWords_psychology_corpus = random.sample(model.get_words(), numWords)

wordsSubMatrix_psychology_corpus = []
for word in targetWords_psychology_corpus:
    wordsSubMatrix_psychology_corpus.append(psychology_corpus_W2V.wv[word])
wordsSubMatrix_psychology_corpus = np.array(wordsSubMatrix_psychology_corpus)

# %% [markdown]
# First, use PCA to do dimension reduction:

# %%
pcaWords_psychology_corpus = sklearn.decomposition.PCA(n_components = 2).fit(wordsSubMatrix_psychology_corpus)
reducedPCA_data_psychology_corpus = pcaWords.transform(wordsSubMatrix_psychology_corpus)

# %%
# Visualize
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(reducedPCA_data_psychology_corpus[:, 0], reducedPCA_data_psychology_corpus[:, 1], alpha = 0)#Making the points invisible
for i, word in enumerate(targetWords_psychology_corpus):
    ax.annotate(word, (reducedPCA_data_psychology_corpus[:, 0][i], reducedPCA_data_psychology_corpus[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Then, use TSNE to do dimension reduction:

# %%
tsne = sklearn.manifold.TSNE(n_components = 2, perplexity=30, learning_rate=200)
tsneWords_psychology_corpus = tsne.fit_transform(wordsSubMatrix_psychology_corpus)

# %%
# Visualize
fig = plt.figure(figsize = (10,6))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWords_psychology_corpus[:, 0], tsneWords_psychology_corpus[:, 1], alpha = 0)#Making the points invisible
for i, word in enumerate(targetWords_psychology_corpus):
    ax.annotate(word, (tsneWords_psychology_corpus[:, 0][i], tsneWords_psychology_corpus[:, 1][i]), size =  20 * (numWords - i) / numWords)
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Here, I will interrogate critical word vectors within the corpus for `fasttext`:

# %%
# Find simialr words
similar_words_ft = {word: model.get_nearest_neighbors(word, k=10) for word in target_words}
similar_words_ft
# Out:
# {'cognitive': [(0.96799236536026, 'noncognitive'),
#   (0.9414506554603577, 'neurocognitive'),
#   (0.9121626019477844, 'sociocognitive'),
#   (0.9037158489227295, 'metacognitive'),
#   (0.8413006663322449, 'engineeringcognitive'),
#   (0.8325055837631226, 'neurodegenerative'),
#   (0.8263337016105652, 'cognitively'),
#   (0.793895959854126, 'robotic'),
#   (0.7619947195053101, 'music'),
#   (0.7602205872535706, 'compulsive')],
#  'memory': [(0.9447013139724731, 'emory'),
#   (0.9246339797973633, 'sensory'),
#   (0.8866230845451355, 'sensori'),
#   (0.8854328989982605, 'sensor'),
#   (0.8690142035484314, 'sensorimotor'),
#   (0.8548917770385742, 'speech'),
#   (0.8445123434066772, 'image'),
#   (0.8248124122619629, 'imagery'),
#   (0.8206160664558411, 'rhythm'),
#   (0.8100226521492004, 'symbol')],
#  'disorder': [(0.9652374386787415, 'disorders'),
#   (0.9348548054695129, 'disordered'),
#   (0.8936392068862915, 'diagnosis'),
#   (0.8769386410713196, 'diachronic'),
#   (0.8657975196838379, 'diagnose'),
#   (0.8615148067474365, 'schizophrenic'),
#   (0.8540540933609009, 'diaz'),
#   (0.853101372718811, 'chronic'),
#   (0.8478009104728699, 'dis'),
#   (0.8452466726303101, 'diagnostic')],
#  'attention': [(0.980842649936676, 'inattention'),
#   (0.9200029969215393, 'contention'),
#   (0.8920219540596008, 'detention'),
#   (0.8830379843711853, 'nutrition'),
#   (0.8812760710716248, 'ambition'),
#   (0.8783449530601501, 'retention'),
#   (0.8682464957237244, 'reception'),
#   (0.867755651473999, 'mention'),
#   (0.8607076406478882, 'inception'),
#   (0.8575181365013123, 'deception')],
#  'social': [(0.9356953501701355, 'asocial'),
#   (0.8999164700508118, 'biosocial'),
#   (0.8773564100265503, 'parasocial'),
#   (0.8766220808029175, 'societal'),
#   (0.8406546711921692, 'antisocial'),
#   (0.8271852731704712, 'sociopolitical'),
#   (0.82076096534729, 'prosocial'),
#   (0.7999469041824341, 'socio'),
#   (0.7915332913398743, 'sociale'),
#   (0.7768771648406982, 'socioeconomic')],
#  'developmental': [(0.9339168667793274, 'neurodevelopmental'),
#   (0.8875977396965027, 'development'),
#   (0.7817105650901794, 'developmentally'),
#   (0.7744665741920471, 'developments'),
#   (0.7290550470352173, 'central'),
#   (0.705581784248352, 'hcd'),
#   (0.6983436942100525, 'develops'),
#   (0.6933227181434631, 'emergent'),
#   (0.6835174560546875, 'psychodynamics'),
#   (0.6783668994903564, 'broader')]}

# %%
# Find word analogy
import scipy

# Define a function to do addition and subtraction based on vector algebra
def analogy_ft(A, B, C, fasttext_model, topn=1):
    # Get the vectors for each word
    A_vec = fasttext_model.get_word_vector(A)
    B_vec = fasttext_model.get_word_vector(B)
    C_vec = fasttext_model.get_word_vector(C)

    # Compute the result vector
    result_vec = B_vec - A_vec + C_vec

    # Compute cosine similarity between result_vec and all word vectors in the model
    word_similarities = {word: 1 - scipy.spatial.distance.cosine(result_vec, fasttext_model.get_word_vector(word))
                         for word in fasttext_model.get_words()}

    # Sort words by similarity
    sorted_words = sorted(word_similarities.items(), key=lambda item: item[1], reverse=True)

    # Return the topn most similar words, skipping the first one as it's usually the input word itself
    return sorted_words[:topn]

print(analogy_ft('mental', 'disorder', 'developmental', model))
print(analogy_ft('cognitive', 'ability', 'social', model))
# Out:
# [('disorder', 0.8484290242195129)]
# [('sociability', 0.8279461860656738)]

# %% [markdown]
# **General Discussion**:
#
# - The simialrity analysis is what I think speaks best of the particular semantic organization of words in my corpora. For instance, for the word "developental," we can see words such as "evolutionary" and "lifespan" that makes much sense. In addition, for the word "disorder", we can see words such as "diachronic", "schizophrenic", and "diagnosis" that makes much sense. Together, they point to the semantic organization. Some words in psychology are similar in terms of morphology while others are similar in terms of semantics.
#
# - `Fasttext` word embedding method, together with the `cbow` and `TSNE` dimension reduction (for visualization), generates the most insight both in terms of visualization results and similarity and analogy analyses. One reason behind is that `fasttext` word embedding method capture the rich morphological features of words and boasts more tolerance towards wrongly spelled words. Another reason is that `TSNE` is better than `PCA` in terms of capturing the non-linear relationship between words and words/contexts.

# %% [markdown]
# # Doc2Vec

# %% [markdown]
# Instead of just looking at just how words embed within in the space, we can look at how the different documents relate to each other within the space. First lets load our data--abstracts of most U.S. physics papers from the 1950s.

# %%
apsDF = pd.read_csv('APSabstracts1950s.csv', index_col = 0)

apsDF[:10]
# Out:
#    copyrightYear                        doi  \
# 0           1950  10.1103/RevModPhys.22.221
# 1           1951  10.1103/RevModPhys.23.147
# 2           1951  10.1103/RevModPhys.23.185
# 3           1951  10.1103/RevModPhys.23.203
# 4           1951   10.1103/RevModPhys.23.21
# 5           1951  10.1103/RevModPhys.23.311
# 6           1951  10.1103/RevModPhys.23.315
# 7           1951  10.1103/RevModPhys.23.322
# 8           1951  10.1103/RevModPhys.23.328
# 9           1952  10.1103/RevModPhys.24.108
#
#                                             abstract
# 0  A summarizing account is given of the research...
# 1  New tables of coulomb functions are presented ...
# 2  Ionization by electron impact in diatomic gase...
# 3  It is shown that the conductivity in the ohmic...
# 4  The factorization method is an operational pro...
# 5  A brief account is given of Dyson's proof of t...
# 6  A systematics is given of all transitions for ...
# 7  A systematics of the -transitions of even A nu...
# 8  The available experiments on the absorption sp...
# 9  The classical theory of the dynamics of viscou...

# %% [markdown]
# We will load these as documents into Word2Vec, but first we need to normalize and pick some tags.

# %%
keywords = ['photomagnetoelectric', 'quantum', 'boltzmann', 'proton', 'positron', 'feynman', 'classical', 'relativity']

# %%
apsDF['tokenized_words'] = apsDF['abstract'].apply(lambda x: lucem_illud.word_tokenize(x))
apsDF['normalized_words'] = apsDF['tokenized_words'].apply(lambda x: lucem_illud.normalizeTokens(x, lemma=False))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
from gensim.models.doc2vec import TaggedDocument

taggedDocs = []
for index, row in apsDF.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['copyrightYear'])
    docKeywords.append(row['doi']) #This lets us extract individual documnets since doi's are unique
    taggedDocs.append(gensim.models.doc2vec.TaggedDocument(words = row['normalized_words'], tags = docKeywords))
apsDF['TaggedAbstracts'] = taggedDocs

# %% [markdown]
# Now we can train a Doc2Vec model:

# %%
apsD2V = gensim.models.doc2vec.Doc2Vec(apsDF['TaggedAbstracts'], vector_size = 100) #Limiting to 100 dimensions
# Out:
# WARNING:gensim.models.doc2vec:More unique tags (9717) than documents (9709).

# %% [markdown]
# We can get vectors for the tags/documents, just as we did with words. Documents are actually the centroids (high dimensional average points) of their words.

# %%
apsD2V.docvecs[1952]
# Out:
# array([ 0.17181163,  1.971629  , -0.86698085,  0.6419243 ,  0.6129144 ,
#         1.1686362 , -0.3790102 ,  0.26621646,  1.1049868 , -0.9640349 ,
#        -1.1178436 , -0.8070163 ,  0.5185582 , -0.40895084, -0.9865325 ,
#         0.8371079 , -0.29231405,  0.29161775,  0.59756553, -1.2935795 ,
#         1.1704687 ,  1.6722871 ,  0.7961489 ,  0.82660705, -1.9275316 ,
#        -0.8206311 ,  1.6623964 ,  0.41333857,  0.2655596 ,  0.8708195 ,
#         0.42974502, -0.23455943, -0.5169039 ,  1.1584927 , -1.7233324 ,
#        -0.36329538,  1.0890714 , -0.32179102, -1.0614524 , -1.9596035 ,
#         1.6232164 , -0.77070904, -1.3951645 ,  0.79453546, -1.867166  ,
#         0.2022315 , -1.9590666 , -1.1133137 , -1.966229  ,  0.8067562 ,
#        -1.500061  , -0.11287843,  0.65433943, -0.17740184, -1.8157912 ,
#        -1.7303252 ,  0.24115665,  0.34796846, -0.23800786, -0.6183959 ,
#        -1.6320906 , -0.8387875 ,  1.078607  , -0.61191416, -1.1424114 ,
#        -1.4994903 ,  0.839549  ,  0.27440006, -2.2325883 ,  1.1245838 ,
#        -0.26810822, -0.6182465 , -1.0978118 , -0.27301392, -1.346978  ,
#        -0.39605376,  0.39955425,  0.08883663, -1.3707304 ,  0.92843735,
#         0.26138192, -0.37495598, -0.99163616,  0.16798164, -0.9563367 ,
#         0.00493347, -1.32839   ,  0.4733754 , -1.3305045 ,  0.06810966,
#         1.1095245 ,  1.0339226 , -2.585969  , -0.9563562 ,  0.4984662 ,
#        -0.87871253,  2.1715312 , -0.28620696, -0.5761657 ,  0.09692045],
#       dtype=float32)

# %% [markdown]
# The words can still be accessed in the same way:

# %%
apsD2V['atom']
# Out:
# array([-1.4242754 , -1.322619  ,  1.1054469 , -0.7193412 ,  1.1555543 ,
#         0.11050887, -0.3654697 ,  0.980828  ,  0.19256249,  0.14131209,
#        -0.8809601 ,  0.15684813, -0.15309611,  0.51935315, -0.44385433,
#         1.7055346 , -0.38666755,  1.6949948 ,  0.12340868, -1.66729   ,
#        -2.2019672 ,  0.9542264 ,  0.21236256,  1.3630347 ,  0.02182803,
#        -0.14283715,  0.10210929,  0.12395934, -0.50225896,  0.78969747,
#         0.5718688 , -0.7196917 , -0.21970068,  0.49117354, -0.65353596,
#        -0.5962321 ,  0.42258784, -0.17108521,  0.2493383 , -0.67798394,
#         1.5230786 ,  0.57053274, -1.1081583 , -1.5977118 ,  1.2860764 ,
#        -0.03339134, -0.85451806,  0.8137517 , -0.36353505,  1.7132565 ,
#         0.21995115,  0.45482036,  1.620533  , -0.48533657,  0.61261624,
#         0.11344907,  0.15075028, -0.82269675,  1.6338406 ,  0.142779  ,
#        -1.040129  , -0.38633734,  0.393176  , -0.451689  , -1.3700595 ,
#        -0.6088315 , -0.30284402, -0.937112  ,  0.06554045,  0.07462027,
#         0.32782376,  0.7951746 , -0.43079743, -2.1583643 , -0.76417893,
#         1.0019623 ,  1.7106676 , -1.0096636 ,  0.61321646,  0.25417295,
#         0.7763388 , -0.4790064 ,  0.23503163,  0.4863204 , -0.58254945,
#        -1.704746  , -1.8126677 , -0.00246439,  0.89351   ,  0.11284694,
#         0.38525173,  0.48203653,  0.8306854 ,  0.7179239 ,  0.8140701 ,
#         0.07177033,  0.10653333,  0.86226684, -1.0931809 ,  1.5228851 ],
#       dtype=float32)

# %% [markdown]
# We can still use the ``most_similar`` command to perform simple semantic equations:

# %%
apsD2V.wv.most_similar(positive = ['atom','electrons'], negative = ['electron'], topn = 1)
# Out:
# [('atoms', 0.7831116318702698)]

# %% [markdown]
# This is interesting. **Electron** is to **electrons** as **atom** is to **atoms**. Another way to understand this, developed below is: **electrons - electron** induces a singular to plural dimension, so when we subtract **electron** from **atom** and add **electrons**, we get **atoms**!

# %%
apsD2V.wv.most_similar(positive = ['einstein','law'], negative = ['equation'], topn = 1)
# Out:
# [('obey', 0.698609471321106)]

# %% [markdown]
# In other words **Einstein** minus **equation** plus **law** equals **Meissner**--Walthur Meissner studied mechanical engineering and physics ... and was more likely to produce a "law" than a "equation", like the Meissner effect, the damping of the magnetic field in superconductors. If we built our word-embedding with a bigger corpus like the entire arXiv, a massive repository of physics preprints, we would see many more such relationships like **gravity - Newton + Einstein = relativity**.

# %% [markdown]
# We can also compute all of these *by hand*--explicitly wth vector algebra:

# %%
sklearn.metrics.pairwise.cosine_similarity(apsD2V['electron'].reshape(1,-1), apsD2V['positron'].reshape(1,-1))
#We reorient the vectors with .reshape(1, -1) so that they can be computed without a warning in sklearn
# Out:
# array([[0.45383012]], dtype=float32)

# %% [markdown]
# In the doc2vec model, the documents have vectors just as the words do, so that we can compare documents with each other and also with words (similar to how a search engine locates a webpage with a query). First, we will calculate the distance between a word and documents in the dataset:

# %%
apsD2V.docvecs.most_similar([ apsD2V['electron'] ], topn=5 )
# Out:
# [('10.1103/PhysRev.113.1545', 0.5275902152061462),
#  ('10.1103/PhysRev.112.334', 0.446575403213501),
#  ('10.1103/PhysRev.115.678', 0.41805168986320496),
#  ('10.1103/PhysRev.114.644', 0.412951797246933),
#  ('10.1103/PhysRev.104.584', 0.40032005310058594)]

# %% [markdown]
# If we search for the first of these on the web (these are doi codes), we find the following...a pretty good match:

# %%
from IPython.display import Image
Image("PhysRev.98.875.jpg", width=1000, height=1000)

# %% [markdown]
# Now let's go the other way around and find words most similar to this document:

# %%
apsD2V.wv.most_similar( [ apsD2V.docvecs['10.1103/PhysRev.98.875'] ], topn=5)
# Out:
# [('microscope', 0.6178924441337585),
#  ('electromagnetic', 0.594433605670929),
#  ('attainable', 0.5913365483283997),
#  ('loeb', 0.5861228108406067),
#  ('radio', 0.5816642642021179)]

# %% [markdown]
# We can even look for documents most like a query composed of multiple words:

# %%
apsD2V.docvecs.most_similar([ apsD2V['electron']+apsD2V['positron']+apsD2V['neutron']], topn=5 )
# Out:
# [('10.1103/PhysRev.102.466', 0.5027457475662231),
#  ('10.1103/PhysRev.115.349', 0.49910175800323486),
#  ('10.1103/PhysRev.108.809', 0.4848974049091339),
#  ('10.1103/PhysRev.91.885', 0.48095202445983887),
#  ('10.1103/PhysRev.110.451', 0.47701919078826904)]

# %% [markdown]
# Now let's plot some words and documents against one another with a heatmap:

# %%
heatmapMatrix = []
for tagOuter in keywords:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrix.append(column)
heatmapMatrix = np.array(heatmapMatrix)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrix, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrix.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrix.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(keywords, minor=False)

# %% [markdown]
# Now let's look at a heatmap of similarities between the first ten documents in the corpus:

# %%
targetDocs = apsDF['doi'][:10]

heatmapMatrixD = []

for tagOuter in targetDocs:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in targetDocs:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixD.append(column)
heatmapMatrixD = np.array(heatmapMatrixD)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixD, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixD.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixD.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(targetDocs, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# Now let's look at a heatmap of similarities between the first ten documents and our keywords:

# %%
heatmapMatrixC = []

for tagOuter in targetDocs:
    column = []
    tagVec = apsD2V.docvecs[tagOuter].reshape(1, -1)
    for tagInner in keywords:
        column.append(sklearn.metrics.pairwise.cosine_similarity(tagVec, apsD2V.docvecs[tagInner].reshape(1, -1))[0][0])
    heatmapMatrixC.append(column)
heatmapMatrixC = np.array(heatmapMatrixC)

# %%
fig, ax = plt.subplots()
hmap = ax.pcolor(heatmapMatrixC, cmap='terrain')
cbar = plt.colorbar(hmap)

cbar.set_label('cosine similarity', rotation=270)
a = ax.set_xticks(np.arange(heatmapMatrixC.shape[1]) + 0.5, minor=False)
a = ax.set_yticks(np.arange(heatmapMatrixC.shape[0]) + 0.5, minor=False)

a = ax.set_xticklabels(keywords, minor=False, rotation=270)
a = ax.set_yticklabels(targetDocs, minor=False)

# %% [markdown]
# We will save the model in case we would like to use it again.

# %%
apsD2V.save('apsW2V')

# %% [markdown]
# We can later load it:

# %%
#apsD2V = gensim.models.word2vec.Word2Vec.load('data/apsW2V')

# %% [markdown]
# ## <font color="red">*Exercise 2*</font>
#
# <font color="red">Construct cells immediately below this that embed documents related to your final project using `doc2vec`, and explore the relationship between different documents and the word vectors you analyzed in the last exercise. Consider the most similar words to critical documents, analogies (doc _x_ + word _y_), and other additions and subtractions that reveal the structure of similarity and difference within your semantic space. What does this pattern reveal about the documentary organization of your semantic space?

# %%
keywords = ["attention", "bias", "cognitive", "lifespan", "trend", "neuron", "memory", "social", "perception"]

# %%
psychology_corpus['tokenized_words'] = psychology_corpus['Abstract'].apply(lambda x: lucem_illud.word_tokenize(x))
psychology_corpus['normalized_words'] = psychology_corpus['tokenized_words'].apply(lambda x: lucem_illud.normalizeTokens(x, lemma=False))
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
psychology_corpus.head()
# Out:
#    Year FieldOfStudy                                              Title  \
# 0  2003   Psychology  Maps of Bounded Rationality: Psychology for Be...
# 1  2003   Psychology  DSM-Oriented and Empirically Based Approaches ...
# 2  2003   Psychology  Does father absence place daughters at special...
# 3  2003   Psychology                         The Psychology of the Body
# 4  2003   Psychology  Validation of the Female Sexual Function Index...
#
#                                               Author  \
# 0                                        D. Kahneman
# 1              T. Achenbach, L. Dumenci, L. Rescorla
# 2  B. Ellis, J. Bates, K. Dodge, D. Fergusson, L....
# 3                   E. Greene, Barbara Goodrich-Dunn
# 4                                          C. Meston
#
#                                             Abstract  \
# 0  The work cited by the Nobel committee was done...
# 1  Department of Psychology, Bryn Mawr College Se...
# 2  The impact of father absence on early sexual a...
# 3  Section I: The Body Organizes Experience1. The...
# 4  Department of Psychology, University of Texas ...
#
#                                      tokenized_sents  \
# 0  [[The, work, cited, by, the, Nobel, committee,...
# 1  [[Department, of, Psychology, Bryn, Mawr, Coll...
# 2  [[The, impact, of, father, absence, on, early,...
# 3  [[Section, I, The, Body, Organizes, Experience...
# 4  [[Department, of, Psychology, University, of, ...
#
#                                     normalized_sents  \
# 0  [[work, cited, nobel, committee, jointly, amos...
# 1  [[department, psychology, bryn, mawr, college,...
# 2  [[impact, father, absence, early, sexual, acti...
# 3  [[section, body, organizes, experience1], [psy...
# 4  [[department, psychology, university, texas, a...
#
#                                      tokenized_words  \
# 0  [The, work, cited, by, the, Nobel, committee, ...
# 1  [Department, of, Psychology, Bryn, Mawr, Colle...
# 2  [The, impact, of, father, absence, on, early, ...
# 3  [Section, I, The, Body, Organizes, Experience1...
# 4  [Department, of, Psychology, University, of, T...
#
#                                     normalized_words
# 0  [work, cited, nobel, committee, jointly, amos,...
# 1  [department, psychology, bryn, mawr, college, ...
# 2  [impact, father, absence, early, sexual, activ...
# 3  [section, body, organizes, experience1, psycho...
# 4  [department, psychology, university, texas, au...

# %%
taggedDocs = []
for index, row in psychology_corpus.iterrows():
    #Just doing a simple keyword assignment
    docKeywords = [s for s in keywords if s in row['normalized_words']]
    docKeywords.append(row['Year'])
    docKeywords.append(row['Title']) #This lets us extract individual documnets since doi's are unique
    taggedDocs.append(gensim.models.doc2vec.TaggedDocument(words = row['normalized_words'], tags = docKeywords))
psychology_corpus['TaggedAbstracts'] = taggedDocs

# %%
psychology_corpus_D2V = gensim.models.doc2vec.Doc2Vec(psychology_corpus['TaggedAbstracts'], vector_size = 100) #Limiting to 100 dimensions

# %% [markdown]
# We can get vectors for the tags/documents, just as we did with words. Documents are actually the centroids (high dimensional average points) of their words.

# %%
apsD2V.docvecs[1952]
# Out:
# array([ 0.17181163,  1.971629  , -0.86698085,  0.6419243 ,  0.6129144 ,
#         1.1686362 , -0.3790102 ,  0.26621646,  1.1049868 , -0.9640349 ,
#        -1.1178436 , -0.8070163 ,  0.5185582 , -0.40895084, -0.9865325 ,
#         0.8371079 , -0.29231405,  0.29161775,  0.59756553, -1.2935795 ,
#         1.1704687 ,  1.6722871 ,  0.7961489 ,  0.82660705, -1.9275316 ,
#        -0.8206311 ,  1.6623964 ,  0.41333857,  0.2655596 ,  0.8708195 ,
#         0.42974502, -0.23455943, -0.5169039 ,  1.1584927 , -1.7233324 ,
#        -0.36329538,  1.0890714 , -0.32179102, -1.0614524 , -1.9596035 ,
#         1.6232164 , -0.77070904, -1.3951645 ,  0.79453546, -1.867166  ,
#         0.2022315 , -1.9590666 , -1.1133137 , -1.966229  ,  0.8067562 ,
#        -1.500061  , -0.11287843,  0.65433943, -0.17740184, -1.8157912 ,
#        -1.7303252 ,  0.24115665,  0.34796846, -0.23800786, -0.6183959 ,
#        -1.6320906 , -0.8387875 ,  1.078607  , -0.61191416, -1.1424114 ,
#        -1.4994903 ,  0.839549  ,  0.27440006, -2.2325883 ,  1.1245838 ,
#        -0.26810822, -0.6182465 , -1.0978118 , -0.27301392, -1.346978  ,
#        -0.39605376,  0.39955425,  0.08883663, -1.3707304 ,  0.92843735,
#         0.26138192, -0.37495598, -0.99163616,  0.16798164, -0.9563367 ,
#         0.00493347, -1.32839   ,  0.4733754 , -1.3305045 ,  0.06810966,
#         1.1095245 ,  1.0339226 , -2.585969  , -0.9563562 ,  0.4984662 ,
#        -0.87871253,  2.1715312 , -0.28620696, -0.5761657 ,  0.09692045],
#       dtype=float32)

# %% [markdown]
# The words can still be accessed in the same way:

# %%
apsD2V['atom']
# Out:
# array([-1.4242754 , -1.322619  ,  1.1054469 , -0.7193412 ,  1.1555543 ,
#         0.11050887, -0.3654697 ,  0.980828  ,  0.19256249,  0.14131209,
#        -0.8809601 ,  0.15684813, -0.15309611,  0.51935315, -0.44385433,
#         1.7055346 , -0.38666755,  1.6949948 ,  0.12340868, -1.66729   ,
#        -2.2019672 ,  0.9542264 ,  0.21236256,  1.3630347 ,  0.02182803,
#        -0.14283715,  0.10210929,  0.12395934, -0.50225896,  0.78969747,
#         0.5718688 , -0.7196917 , -0.21970068,  0.49117354, -0.65353596,
#        -0.5962321 ,  0.42258784, -0.17108521,  0.2493383 , -0.67798394,
#         1.5230786 ,  0.57053274, -1.1081583 , -1.5977118 ,  1.2860764 ,
#        -0.03339134, -0.85451806,  0.8137517 , -0.36353505,  1.7132565 ,
#         0.21995115,  0.45482036,  1.620533  , -0.48533657,  0.61261624,
#         0.11344907,  0.15075028, -0.82269675,  1.6338406 ,  0.142779  ,
#        -1.040129  , -0.38633734,  0.393176  , -0.451689  , -1.3700595 ,
#        -0.6088315 , -0.30284402, -0.937112  ,  0.06554045,  0.07462027,
#         0.32782376,  0.7951746 , -0.43079743, -2.1583643 , -0.76417893,
#         1.0019623 ,  1.7106676 , -1.0096636 ,  0.61321646,  0.25417295,
#         0.7763388 , -0.4790064 ,  0.23503163,  0.4863204 , -0.58254945,
#        -1.704746  , -1.8126677 , -0.00246439,  0.89351   ,  0.11284694,
#         0.38525173,  0.48203653,  0.8306854 ,  0.7179239 ,  0.8140701 ,
#         0.07177033,  0.10653333,  0.86226684, -1.0931809 ,  1.5228851 ],
#       dtype=float32)

# %% [markdown]
# We can still use the ``most_similar`` command to perform simple semantic equations:

# %%
apsD2V.wv.most_similar(positive = ['atom','electrons'], negative = ['electron'], topn = 1)
# Out:
# [('atoms', 0.7831116318702698)]

# %% [markdown]
# This is interesting. **Electron** is to **electrons** as **atom** is to **atoms**. Another way to understand this, developed below is: **electrons - electron** induces a singular to plural dimension, so when we subtract **electron** from **atom** and add **electrons**, we get **atoms**!

# %%
apsD2V.wv.most_similar(positive = ['einstein','law'], negative = ['equation'], topn = 1)
# Out:
# [('obey', 0.698609471321106)]

# %% [markdown]
# In other words **Einstein** minus **equation** plus **law** equals **Meissner**--Walthur Meissner studied mechanical engineering and physics ... and was more likely to produce a "law" than a "equation", like the Meissner effect, the damping of the magnetic field in superconductors. If we built our word-embedding with a bigger corpus like the entire arXiv, a massive repository of physics preprints, we would see many more such relationships like **gravity - Newton + Einstein = relativity**.

# %% [markdown]
# We can also compute all of these *by hand*--explicitly wth vector algebra:

# %%
sklearn.metrics.pairwise.cosine_similarity(apsD2V['electron'].reshape(1,-1), apsD2V['positron'].reshape(1,-1))
#We reorient the vectors with .reshape(1, -1) so that they can be computed without a warning in sklearn
# Out:
# array([[0.45383012]], dtype=float32)

# %% [markdown]
# In the doc2vec model, the documents have vectors just as the words do, so that we can compare documents with each other and also with words (similar to how a search engine locates a webpage with a query). First, we will calculate the distance between a word and documents in the dataset:

# %%
apsD2V.docvecs.most_similar([ apsD2V['electron'] ], topn=5 )
# Out:
# [('10.1103/PhysRev.113.1545', 0.5275902152061462),
#  ('10.1103/PhysRev.112.334', 0.446575403213501),
#  ('10.1103/PhysRev.115.678', 0.41805168986320496),
#  ('10.1103/PhysRev.114.644', 0.412951797246933),
#  ('10.1103/PhysRev.104.584', 0.40032005310058594)]

# %% [markdown]
# # Projection

# %% [markdown]
# We can also project word vectors to an arbitray semantic dimension. To demonstrate this possibility, let's first load a model trained with New York Times news articles.

# %%
nytimes_model = gensim.models.KeyedVectors.load_word2vec_format('nytimes_cbow.reduced.txt')

# %% [markdown]
# First we can visualize with dimension reduction

# %%
#words to create dimensions
tnytTargetWords = ['man','him','he', 'woman', 'her', 'she', 'black','blacks','African', 'white', 'whites', 'Caucasian', 'rich', 'richer', 'richest', 'expensive', 'wealthy', 'poor', 'poorer', 'poorest', 'cheap', 'inexpensive']
#words we will be mapping
tnytTargetWords += ["doctor","lawyer","plumber","scientist","hairdresser", "nanny","carpenter","entrepreneur","musician","writer", "banker","poet","nurse", "steak", "bacon", "croissant", "cheesecake", "salad", "cheeseburger", "vegetables", "beer", "wine", "pastry", "basketball", "baseball", "boxing", "softball", "volleyball", "tennis", "golf", "hockey", "soccer"]


wordsSubMatrix = []
for word in tnytTargetWords:
    wordsSubMatrix.append(nytimes_model[word])
wordsSubMatrix = np.array(wordsSubMatrix)
#wordsSubMatrix

# %%
pcaWordsNYT = sklearn.decomposition.PCA(n_components = 50).fit(wordsSubMatrix)
reducedPCA_dataNYT = pcaWordsNYT.transform(wordsSubMatrix)
#T-SNE is theoretically better, but you should experiment
tsneWordsNYT = sklearn.manifold.TSNE(n_components = 2).fit_transform(reducedPCA_dataNYT)

# %%
fig = plt.figure(figsize = (20,12))
ax = fig.add_subplot(111)
ax.set_frame_on(False)
plt.scatter(tsneWordsNYT[:, 0], tsneWordsNYT[:, 1], alpha = 0) #Making the points invisible
for i, word in enumerate(tnytTargetWords):
    ax.annotate(word, (tsneWordsNYT[:, 0][i],tsneWordsNYT[:, 1][i]), size =  50 * (len(tnytTargetWords) - i) / len(tnytTargetWords))
plt.xticks(())
plt.yticks(())
plt.show()

# %% [markdown]
# Define some convenient functions for getting dimensions.

# %%
def normalize(vector):
    normalized_vector = vector / np.linalg.norm(vector)
    return normalized_vector

def dimension(model, positives, negatives):
    diff = sum([normalize(model[x]) for x in positives]) - sum([normalize(model[y]) for y in negatives])
    return diff

# %% [markdown]
# Let's calculate three dimensions: gender, race, and class.

# %%
Gender = dimension(nytimes_model, ['man','him','he'], ['woman', 'her', 'she'])
Race = dimension(nytimes_model, ['black','blacks','African'], ['white', 'whites', 'Caucasian'])
Class = dimension(nytimes_model, ['rich', 'richer', 'richest', 'expensive', 'wealthy'], ['poor', 'poorer', 'poorest', 'cheap', 'inexpensive'])

# %% [markdown]
# Here we have some words.

# %%
Occupations = ["doctor","lawyer","plumber","scientist","hairdresser", "nanny","carpenter","entrepreneur","musician","writer", "banker","poet","nurse"]

Foods = ["steak", "bacon", "croissant", "cheesecake", "salad", "cheeseburger", "vegetables", "beer", "wine", "pastry"]

Sports  = ["basketball", "baseball", "boxing", "softball", "volleyball", "tennis", "golf", "hockey", "soccer"]

# %% [markdown]
# Define a function to project words in a word list to each of the three dimensions.

# %%
def makeDF(model, word_list):
    g = []
    r = []
    c = []
    for word in word_list:
        g.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Gender.reshape(1,-1))[0][0])
        r.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Race.reshape(1,-1))[0][0])
        c.append(sklearn.metrics.pairwise.cosine_similarity(nytimes_model[word].reshape(1,-1), Class.reshape(1,-1))[0][0])
    df = pd.DataFrame({'gender': g, 'race': r, 'class': c}, index = word_list)
    return df

# %% [markdown]
# Get the projections.

# %%
OCCdf = makeDF(nytimes_model, Occupations)
Fooddf = makeDF(nytimes_model, Foods)
Sportsdf = makeDF(nytimes_model, Sports)

# %% [markdown]
# Define some useful functions for plotting.

# %%
def Coloring(Series):
    x = Series.values
    y = x-x.min()
    z = y/y.max()
    c = list(plt.cm.rainbow(z))
    return c

def PlotDimension(ax,df, dim):
    ax.set_frame_on(False)
    ax.set_title(dim, fontsize = 20)
    colors = Coloring(df[dim])
    for i, word in enumerate(df.index):
        ax.annotate(word, (0, df[dim][i]), color = colors[i], alpha = 0.6, fontsize = 12)
    MaxY = df[dim].max()
    MinY = df[dim].min()
    plt.ylim(MinY,MaxY)
    plt.yticks(())
    plt.xticks(())

# %% [markdown]
# Plot the occupational words in each of the three dimensions.

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, OCCdf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, OCCdf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, OCCdf, 'class')
plt.show()

# %% [markdown]
# Foods:

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, Fooddf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, Fooddf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, Fooddf, 'class')
plt.show()

# %% [markdown]
# Sports:

# %%
fig = plt.figure(figsize = (12,4))
ax1 = fig.add_subplot(131)
PlotDimension(ax1, Sportsdf, 'gender')
ax2 = fig.add_subplot(132)
PlotDimension(ax2, Sportsdf, 'race')
ax3 = fig.add_subplot(133)
PlotDimension(ax3, Sportsdf, 'class')
plt.show()

# %% [markdown]
# ## <font color="red">*Exercise 3*</font>
#
# <font color="red">Construct cells immediately below this that embed documents related to your final project, then generate meaningful semantic dimensions based on your theoretical understanding of the semantic space (i.e., by subtracting semantically opposite word vectors) and project another set of word vectors onto those dimensions. Interpret the meaning of these projections for your analysis. Which of the dimensions you analyze explain the most variation in the projection of your words and why?
#
# <font color="red">***Stretch***: Average together multiple antonym pairs to create robust semantic dimensions. How do word projections on these robust dimensions differ from single-pair dimensions?

# %% [markdown]
# # Linguistic Change or Difference
#
# Below is code that aligns the dimensions of multiple embeddings arrayed over time or some other dimension and allow identification of semantic chanage as the word vectors change their loadings for focal words. This code comes from the approach piloted at Stanford by William Hamilton, Daniel Jurafsky and Jure Lescovec [here](https://arxiv.org/pdf/1605.09096.pdf).

# %%
import copy

# %%
def calc_syn0norm(model):
    """since syn0norm is now depricated"""
    return (model.wv.syn0 / np.sqrt((model.wv.syn0 ** 2).sum(-1))[..., np.newaxis]).astype(np.float32)

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    """Procrustes align two gensim word2vec models (to allow for comparison between same word across models).
    Code ported from HistWords <https://github.com/williamleif/histwords> by William Hamilton <wleif@stanford.edu>.
    (With help from William. Thank you!)
    First, intersect the vocabularies (see `intersection_align_gensim` documentation).
    Then do the alignment on the other_embed model.
    Replace the other_embed model's syn0 and syn0norm numpy matrices with the aligned version.
    Return other_embed.
    If `words` is set, intersect the two models' vocabulary with the vocabulary in words (see `intersection_align_gensim` documentation).
    """
    base_embed = copy.copy(base_embed)
    other_embed = copy.copy(other_embed)
    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)

    # get the embedding matrices
    # base_vecs = calc_syn0norm(in_base_embed)
    # other_vecs = calc_syn0norm(in_other_embed)
    base_vecs= [in_base_embed.wv.get_vector(w,norm=True) for w in set(in_base_embed.wv.index_to_key)]
    other_vecs= [in_other_embed.wv.get_vector(w,norm=True) for w in set(in_other_embed.wv.index_to_key)]

    # just a matrix dot product with numpy
    m = np.array(other_vecs).T.dot(np.array(base_vecs))
    # SVD method from numpy
    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v)
    # Replace original array with modified one
    # i.e. multiplying the embedding matrix (syn0norm)by "ortho"
    other_embed.wv.vectors =(np.array(other_vecs)).dot(ortho)
    return other_embed

def intersection_align_gensim(m1,m2, words=None):
    """
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    """

    # Get the vocab for each model
    vocab_m1 = set(m1.wv.index_to_key)
    vocab_m2 = set(m2.wv.index_to_key)

    # Find the common vocabulary
    common_vocab = vocab_m1&vocab_m2
    if words: common_vocab&=set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1-common_vocab and not vocab_m2-common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.get_vecattr(w, "count")  + m2.wv.get_vecattr(w, "count") ,reverse=True)

    # Then for each model...
    for m in [m1,m2]:
        # Replace old syn0norm array with new one (with common vocab)
        new_arr = [m.wv.get_vector(w,norm=True) for w in common_vocab]

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        m.index2word = common_vocab
        # old_vocab = m.wv.index_to_key
        new_vocab = []
        k2i={}
        for new_index,word in enumerate(common_vocab):
            new_vocab.append(word)
            k2i[word]=new_index
        m.wv.index_to_key=new_vocab
        m.wv.key_to_index=k2i
        m.wv.vectors=np.array(new_arr)

    return (m1,m2)

# %% [markdown]
# In order to explore this, let's get some data that follows a time trend. We'll look at conference proceedings from the American Society for Clinical Oncologists.

# %%
apsDF = pd.read_csv("APSabstracts1950s.csv", index_col=0)

# %% [markdown]
# Prepare for wor2vec:

# %%
apsDF['tokenized_sents'] = apsDF['abstract'].apply(lambda x: [lucem_illud.word_tokenize(s) for s in lucem_illud.sent_tokenize(x)])
apsDF['normalized_sents'] = apsDF['tokenized_sents'].apply(lambda x: [lucem_illud.normalizeTokens(s) for s in x])
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
apsDF.head()
# Out:
#    copyrightYear                        doi  \
# 0           1950  10.1103/RevModPhys.22.221
# 1           1951  10.1103/RevModPhys.23.147
# 2           1951  10.1103/RevModPhys.23.185
# 3           1951  10.1103/RevModPhys.23.203
# 4           1951   10.1103/RevModPhys.23.21
#
#                                             abstract  \
# 0  A summarizing account is given of the research...
# 1  New tables of coulomb functions are presented ...
# 2  Ionization by electron impact in diatomic gase...
# 3  It is shown that the conductivity in the ohmic...
# 4  The factorization method is an operational pro...
#
#                                      tokenized_sents  \
# 0  [[A, summarizing, account, is, given, of, the,...
# 1  [[New, tables, of, coulomb, functions, are, pr...
# 2  [[Ionization, by, electron, impact, in, diatom...
# 3  [[It, is, shown, that, the, conductivity, in, ...
# 4  [[The, factorization, method, is, an, operatio...
#
#                                     normalized_sents
# 0  [[summarizing, account, given, research, bariu...
# 1  [[new, tables, coulomb, functions, presented, ...
# 2  [[ionization, electron, impact, diatomic, gase...
# 3  [[shown, conductivity, ohmic, cuprous, oxide, ...
# 4  [[factorization, method, operational, procedur...

# %% [markdown]
# We will be creating many embeddings so we have created this function to do most of the work. It creates two collections of embeddings, one the original and one the aligned.

# %%
def compareModels(df, category, text_column_name='normalized_sents', sort = True, embeddings_raw={}):
    """If you are using time as your category sorting is important"""
    if len(embeddings_raw) == 0:
        embeddings_raw = rawModels(df, category, text_column_name, sort)
    cats = sorted(set(df[category]))
    #These are much quicker
    embeddings_aligned = {}
    for catOuter in cats:
        embeddings_aligned[catOuter] = [embeddings_raw[catOuter]]
        for catInner in cats:
            embeddings_aligned[catOuter].append(smart_procrustes_align_gensim(embeddings_aligned[catOuter][-1], embeddings_raw[catInner]))
    return embeddings_raw, embeddings_aligned

# %%
def rawModels(df, category, text_column_name='normalized_sents', sort = True):
    embeddings_raw = {}
    cats = sorted(set(df[category]))
    for cat in cats:
        #This can take a while
        print("Embedding {}".format(cat), end = '\r')
        subsetDF = df[df[category] == cat]
        #You might want to change the W2V parameters
        embeddings_raw[cat] = gensim.models.word2vec.Word2Vec(subsetDF[text_column_name].sum())
    return embeddings_raw

# %% [markdown]
# Now we generate the models:

# %%
rawEmbeddings, comparedEmbeddings = compareModels(apsDF, 'copyrightYear')

# %%
rawEmbeddings.keys()
# Out:
# dict_keys([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959])

# %% [markdown]
# We need to compare them across all permutions so we will define another function to help, we will be using 1 - cosine similarity as that gives a more intitive range of 0-2 with low values meaning little change and high meaning lots of change.

# %%
def getDivergenceDF(word, embeddingsDict):
    dists = []
    cats = sorted(set(embeddingsDict.keys()))
    dists = {}
    print(word)
    for cat in cats:
        dists[cat] = []
        for embed in embeddingsDict[cat][1:]:
            dists[cat].append(np.abs(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cat][0].wv[word], axis = 0),
                                                                             np.expand_dims(embed.wv[word], axis = 0))[0,0]))
    return pd.DataFrame(dists, index = cats)

# %% [markdown]
# Lets look at a couple words:

# %%
targetWord = 'radioactive'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# radioactive

# %%
targetWord = 'area'

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# area

# %%
def findDiverence(word, embeddingsDict):
    cats = sorted(set(embeddingsDict.keys()))

    dists = []
    for embed in embeddingsDict[cats[0]][1:]:
        try:
            dists.append(1 - sklearn.metrics.pairwise.cosine_similarity(np.expand_dims(embeddingsDict[cats[0]][0].wv[word], axis = 0), np.expand_dims(embed.wv[word], axis = 0))[0,0])
        except:
            pass
    return np.mean(dists)

def findMostDivergent(embeddingsDict):
    original_words = comparedEmbeddings[1950][0].wv.index_to_key
    for embeds in embeddingsDict.values():
        for embed in embeds:
            original_words = set(original_words).intersection(set(embed.wv.index_to_key))
    words = set(original_words)
    print("Found {} words to compare".format(len(words)))
    return sorted([(w, findDiverence(w, embeddingsDict)) for w in words], key = lambda x: x[1], reverse=True)

# %%
wordDivergences = findMostDivergent(comparedEmbeddings)
# Out:
# Found 951 words to compare

# %% [markdown]
# The most divergent words are:

# %%
wordDivergences[:20]
# Out:
# [('view', 0.999999717733336),
#  ('application', 0.999999282083872),
#  ('detail', 0.9999992307826308),
#  ('analysis', 0.4096437457966807),
#  ('consistent', 0.40922589674974086),
#  ('low', 0.40518287841565337),
#  ('hamiltonian', 0.3304787203018783),
#  ('charge', 0.3161395451584156),
#  ('found', 0.31411757973429316),
#  ('chemical', 0.3133659305720613),
#  ('activity', 0.3096330310631103),
#  ('total', 0.3083859531123906),
#  ('calculated', 0.3078164709766611),
#  ('path', 0.30707537501447446),
#  ('parity', 0.3064259527503047),
#  ('follows', 0.3061744133789176),
#  ('motion', 0.3060941062675724),
#  ('f', 0.305222539484852),
#  ('discussed', 0.30521335720672305),
#  ('probably', 0.30470073992842545)]

# %% [markdown]
# And the least:

# %%
wordDivergences[-20:]
# Out:
# [('units', 0.00363314151763916),
#  ('scintillation', 0.003612661361694336),
#  ('method', 0.003610867261886597),
#  ('ferromagnetic', 0.0036017894744873047),
#  ('covariant', 0.0035503625869750975),
#  ('interest', 0.0035391867160797117),
#  ('voltage', 0.0035223841667175295),
#  ('domain', 0.003520643711090088),
#  ('angular', 0.0035077393054962157),
#  ('targets', 0.003493255376815796),
#  ('systematic', 0.0034675121307373045),
#  ('spectrum', 0.0034127593040466308),
#  ('cm-1', 0.0032790958881378173),
#  ('additional', 0.003272044658660889),
#  ('tensor', 0.0032386481761932373),
#  ('square', 0.0032058417797088622),
#  ('collisions', 0.003199738264083862),
#  ('g', 0.003012639284133911),
#  ('transitions', 0.002928513288497925),
#  ('presented', 0.002751326560974121)]

# %%
targetWord = wordDivergences[-200][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# resolution

# %%
targetWord = wordDivergences[-1][0]

pltDF = getDivergenceDF(targetWord, comparedEmbeddings)
fig, ax = plt.subplots(figsize = (10, 7))
seaborn.heatmap(pltDF, ax = ax, annot = False) #set annot True for a lot more information
ax.set_xlabel("Starting year")
ax.set_ylabel("Final year")
ax.set_ylabel("Final year")
ax.set_title("Yearly linguistic change for: '{}'".format(targetWord))
plt.show()
# Out:
# presented

# %%
##We only use a small data here so some of the results may not make sense. You can try the algorithm on your own data!

# %% [markdown]
# ## COHA
#
# COHA is a historial dataset so it ends up being a good choice to try the same analysis we just did across three different time periods.
#
# We will be using the same data loading procedure as the last notebook, so go through the process to make sure you know what's going on.

# %%
corpora_address = "COHA"

# %%
coha_texts = lucem_illud.loadDavies(corpora_address, return_raw=True)
# Out:
# text_1810s_kso.zip
# text_1820s_jsi.zip
# text_1830s_bsu.zip
# text_1840s_nsq.zip
# text_1850s_jpr.zip
# text_1860s_psi.zip
# text_1870s_vuy.zip
# text_1880s_azz.zip
# text_1890s_jsq.zip
# text_1900s_mse.zip
# text_1910s_jue.zip
# text_1920s_gte.zip
# text_1930s_bie.zip
# text_1940s_bsw.zip
# text_1950s_ndz.zip
# text_1960s_xus.zip
# text_1970s_jfy.zip
# text_1980s_bkk.zip
# text_1990s_bsj.zip
# text_2000s_scc.zip

# %% [markdown]
# Cool - let us now create our different epochs. This is an important step: I will be using the same 5 epochs I did in the DTM example, but you are recommended to play around with this. I will create a dataframe which logs the year and the genre.

# %%
coha_df = pd.DataFrame(columns=["Year", "Genre", "Epoch", "normalized sents"])

# %%
for article in coha_texts:
    genre, year, id_ = article.split("_")

    year = int(year)

    if year > 1810 and year < 1880:
        epoch = 0
    if year >= 1880 and year < 1913:
        epoch = 1
    if year >= 1913 and year < 1950:
        epoch = 2
    if year >= 1950 and year < 1990:
        epoch = 3
    if year >= 1990:
        epoch = 4

    try:
        if len(coha_texts[article][2]) < 1500000:
            coha_df.loc[id_] = [year, genre, epoch, lucem_illud.normalizeTokens(coha_texts[article][2].decode("utf-8"), lemma=False)]
    except TypeError:
        continue
    except IndexError:
        continue

# %% [markdown]
# We can now arrange our word embeddings by either year, genre, or epoch, and see how the words in each of those contexts change.

# %%
rawEmbeddings_epoch = rawModels(coha_df, 'Epoch', text_column_name='normalized sents')

# %%
# rawEmbeddings_genre = rawModels(coha_df, 'Genre', text_column_name='normalized sents')

# %% [markdown]
# We now have the raw embeddings for epoch and genre. You can test out the previous analysis on words of your choice.

# %%
for epoch, embedding in enumerate(rawEmbeddings_epoch):
    model = rawEmbeddings_epoch[embedding]
    name = "embedding_epoch_" + str(epoch)
    model.save(name)

# %%
# for embedding in rawEmbeddings_genre:
#     model = rawEmbeddings_genre[embedding]
#     name = "embedding_genre_" + embedding
#     model.save(name)

# %%
from gensim.models import Word2Vec

# %%
def file_to_embeddings(address, kind):
    rawEmbeddings = {}
    for file in os.listdir(address):
        if "embedding_"+kind in file:
            e, kind_, kind_type = file.split("_")
            kind_type = eval(kind_type)
            rawEmbeddings[kind_type] = Word2Vec.load(file)
    return rawEmbeddings

# %%
# rawEmbeddings_genre_load = file_to_embeddings(".", "genre")

# %%
rawEmbeddings_epoch_load = file_to_embeddings(".", "epoch")

# %%
rawEmbeddings_epoch_load.keys()

# %%
rawEmbeddings_epoch, compared_epoch = compareModels(coha_df, 'Epoch', text_column_name='normalized sents', embeddings_raw=rawEmbeddings_epoch_load)

# %%
# rawEmbeddings_genre, compared_genre = compareModels(coha_df, 'Genre', text_column_name='normalized sents', embeddings_raw=rawEmbeddings_genre_load)

# %% [markdown]
# You now have access to the epoch wise embeddings, and the code to train models genre wise (commented out). You can use the original embeddings, the compared embeddings and such to perform the analysis we did before.

# %% [markdown]
# ## <font color="red">*Exercise 4*</font>
#
# <font color="red">Construct cells immediately below this that align word embeddings over time or across domains/corpora. Interrogate the spaces that result and ask which words changed most and least over the entire period or between contexts/corpora. What does this reveal about the social game underlying your space?

# %% [markdown]
# There is much more we do not have time to cover on word embeddings. If you are interested in other ways to align word embeddings, take a look at the [Dynamic Word Embeddings (DTM) section from the Thinking with Deep Learning course](https://colab.research.google.com/drive/1RAiI3BIL1X9D4gzZ0rZdIJjkNNicIuKE?usp=sharing#scrollTo=COS_n2RFCJNk) or using the more recent [Temporal Word Embeddings with a Compass (TWEC) package](https://github.com/valedica/twec). There is also a useful section on [debiasing word embeddings](https://colab.research.google.com/drive/1RAiI3BIL1X9D4gzZ0rZdIJjkNNicIuKE?usp=sharing#scrollTo=JHQ--EsWoxGM), such as the famous, ["Man is to Computer Programmer as Woman is to Homemaker? Debiasing Word Embeddings"](https://arxiv.org/abs/1607.06520) paper. Below, we include an optional section on topic modeling with word embeddings, which could be useful for final projects.

# %% [markdown]
# ## Optional: Topic modeling with word embeddings
#
# Recently computer scientists have developed methods to cluster word embeddings, which can be viewed as a topic model, an embedding-based version of conventional topic models that use the document-term matrix (e.g., LDA). One method is Discourse Atoms, first described by Princeton NLP researchers ([Arora et al. 2018](https://arxiv.org/abs/1601.03764)). This uses k-SVD, a generalization of the k-means clustering algorithm to identify topic-like vectors in the n-dimensional word embedding space. Below is code adapted from the first social science paper using Discourse Atoms, [Arseniev-Koehler et al. 2021](https://osf.io/preprints/socarxiv/nkyaq/). It takes as input _gensim_ word vectors.
#
# You are not required to implement this, but for class projects or your own research, this can be more useful than conventional topic models. It runs faster, produces more detailed topics, and in general makes use of more information (i.e., word order within a document) than do conventional topic models. Note there are at least 4 other papers with methods for word embedding clusters:
#
# - Xun, Li, Zhao, Gao, and Zhang 2017: [multivariate Gaussian distributions](https://www.ijcai.org/proceedings/2017/588)
# - Dieng, Ruiz, and Blei 2019: ["Embedding Topic Model (ETM)"](https://arxiv.org/abs/1907.04907)
# - Angelov 2020: ["Top2Vec"](https://arxiv.org/abs/2008.09470)
# - Sia, Dalmia, and Mielke 2020: [(spherical) k-means, k-medoids, von Mises-Fisher Models, Gaussian Mixture Models](https://arxiv.org/abs/2004.14914)
#
# Let's implement the Discourse Atoms method.

# %%
from gensim.test.utils import datapath
import re
import string, re
import cython

# %%
# The ksvd package has a convenient Approximate k-SVD function.
# !pip install ksvd
# Out:
# Collecting ksvd
#   Downloading ksvd-0.0.3-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ksvd) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ksvd) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ksvd) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ksvd) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ksvd) (3.2.0)
# Installing collected packages: ksvd
# Successfully installed ksvd-0.0.3

# %%
from gensim import corpora, models, similarities #calc all similarities at once, from http://radimrehurek.com/gensim/tut3.html
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import KeyedVectors
from random import seed, sample
from ksvd import ApproximateKSVD #pip or conda install ksvd #this is key!

# %%
import pickle

# %%
import math

# %%
# Load a gensim word2vec model
w2v = senReleasesW2V

# %% [markdown]
# #### k-SVD
#
# We then perform a K-SVD on the word embedding matrix to learn topics in such a way where each word-vector is represented as a spare linear combination of topics. To generate a good representation of the original word vector space, we want to minimize the difference between our word vectors and the vectors generated as a linear combination of topics.

# %%
#### TRAIN MODEL:

#n_comp: Number of topics (i.e., atoms, or dictionary elements)
#n_nonzeros: Number of nonzero coefficients to target (how many atoms each word can load onto)

##create the saving folder if you need!!

def do_aksvd(w2vmodel, n_comp, n_nonzeros, save=False, savelocation='/content/aksvd_models/'):
    #https://github.com/nel215/ksvd #takes about 2 min on Alina's laptop for 30 atoms
    aksvd_t = ApproximateKSVD(n_components=n_comp, transform_n_nonzero_coefs=n_nonzeros) #also may adjuste n iter which is default at 10, and tolerance for error which is default at  tol=1e-6 #n_components is number of discourse atoms, since vocab size is smallish, keep this fewer. transform_n is the number of atoms (components) that a word can be a linear combo of
    dictionary_t = aksvd_t.fit(w2vmodel.wv.vectors).components_ # Dictionary is the matrix of discourse atoms.
    alpha_t = aksvd_t.transform(w2vmodel.wv.vectors) #get the alphas, which are the "weights" of each word on a discourse atoms

    if save==True:
        outfile = open(str(savelocation) + '200d_' + str(n_comp) + 'comp' + str(n_nonzeros) + 'nonzeros_aksvd_nvdrsdf20','wb')
        pickle.dump(aksvd_t,outfile)
        outfile.close()

        outfile = open(str(savelocation) + '200d_' +str(n_comp) + 'comp' + str(n_nonzeros) + 'nonzeros_dictionary_nvdrsdf20','wb')
        pickle.dump(dictionary_t,outfile)
        outfile.close()

        outfile = open(str(savelocation) + '200d_' + str(n_comp) + 'comp' + str(n_nonzeros) + 'nonzeros_alpha_nvdrsdf20','wb')
        pickle.dump(alpha_t,outfile)
        outfile.close()
    return(dictionary_t, alpha_t)

# %% [markdown]
# Two quick quality checks. These are useful to choose the number of atoms in the dictionary (i.e., number of topics): $R^2$ and Topic Diversity
#
# Useful to look at product of the two since $R^2$ tends to increase with higher # topics, as Topic Diversity decreases. Intuition: more topics can better explain the original semantic space, but also then these topics are less distinct from one another. As a result, we typically want a balance between the two.

# %%
def reconst_qual(w2vmodel, dictionary_mat, alpha_mat):
    #reconstruct the word vectors
    reconstructed = alpha_mat.dot(dictionary_mat) #reconstruct word vectors and add back in mean(?). but note that reconstructed norm is still around 0-1, not 1, is that an issue?
    #e1 = norm(w2vmodel.wv.vectors - reconstructed) #total reconstruction error, larger means MORE error. norm as specified here takes frobenius norm of error matrix.


    #total VARIANCE in the data: sum of squares
    squares3= w2vmodel.wv.vectors-np.mean(w2vmodel.wv.vectors, axis=1).reshape(-1,1) #https://dziganto.github.io/data%20science/linear%20regression/machine%20learning/python/Linear-Regression-101-Metrics/
    #sst3= np.sum([i.dot(i) for i in squares3] ) #same as below

    sst3= np.sum(np.square(squares3))


    #total sum of squared ERRORS/residuals
    e3= [reconstructed[i]-w2vmodel.wv.vectors[i] for i in range(0,len(w2vmodel.wv.vectors))]  #https://dziganto.github.io/data%20science/linear%20regression/machine%20learning/python/Linear-Regression-101-Metrics/
    #sse3= np.sum([i.dot(i) for i in e3] ) #same as below
    sse3= np.sum(np.square(e3))

    #R^2: 1- (SSE / SST )
    r2= 1- (sse3 /  sst3) #https://stats.stackexchange.com/questions/184603/in-pca-what-is-the-connection-between-explained-variance-and-squared-error


    #compute root mean square error
    rmse=  math.sqrt(np.mean(np.square(e3)))



    return(sse3, rmse, r2) #https://stats.stackexchange.com/questions/184603/in-pca-what-is-the-connection-between-explained-variance-and-squared-error

# %% [markdown]
# #### Inferring topics from document
#
# We now use a similar approach to what we saw a little earlier, where we inverted our generative model to see which documents belong to which class - we do the same now, but with discourse atoms instead of the whole model. This process tells us the topic most likely to have generated a specific context (document).

# %%
#topic diversity (% unique words among total closest 25 words to each atom)
def topic_diversity(w2vmodel, dictionary_mat, top_n=25):

    topwords=[] #list of list, each innter list includes top N words in that topic

    for i in range(0, len(dictionary_mat)): #set to number of total topics
        topwords.extend([i[0] for i in w2vmodel.wv.similar_by_vector(dictionary_mat[i],topn=top_n)]) #set for top N words
        #print(w2vmodel.wv.similar_by_vector(dictionary[i],topn=N))

    uniquewords= set(topwords)
    diversity = len(uniquewords)/len(topwords)
    return(diversity)

# %%
##make sure to create a saving path first

dictionary, alpha = do_aksvd(w2v, 150, 5, save=True)

# %%
topic_diversity(w2v, dictionary, top_n=25)
# Out:
# 0.8034666666666667

# %%
reconst_qual(w2v, dictionary, alpha)
# Out:
# (16714.18224838863, 0.11030937541961874, 0.868297053345052)

# %%
#loading back in the model pieces if not already in

# infile = open('../data/aksvd_models/200d_150comp5nonzeros_dictionary_nvdrsdf20','rb')
# dictionary=pickle.load(infile)
# infile.close()

# infile = open('../data/aksvd_models/200d_150comp5nonzeros_aksvd_nvdrsdf20','rb')
# aksvd=pickle.load(infile)
# infile.close()

# infile = open('../data/aksvd_models/200d_150comp5nonzeros_alpha_nvdrsdf20','rb')
# alpha=pickle.load(infile)
# infile.close()

# %%
for i in range(0, len(dictionary)):
    print("Discourse_Atom " + str(i))
    print([i[0] for i in w2v.wv.similar_by_vector(dictionary[i],topn=25)]) #what are the most similar words to the Nth
    #print([i[0] for i in w2vmodel.wv.similar_by_vector(-dictionary[i],topn=25)]) #what are the most similar words to the Nth dicourse atom?
    print('\n')
# Out:
# Discourse_Atom 0
# ['ends', 'desperately', 'daunting', 'faces', 'obviously', 'facing', 'desperate', 'challenge', 'needs', 'face', 'struggling', 'faced', 'heal', 'tackle', 'urgent', 'struggle', 'challenges', 'dire', 'worse', 'unmet', 'crisis', 'safer', 'confront', 'solve', 'focus']
#
#
# Discourse_Atom 1
# ['forget', 'hopes', 'feel', 'talk', 'stood', 'forever', 'minds', 'moment', 'mind', 'afraid', 'happened', 'remember', 'alive', 'tall', 'lot', 'got', 'pledge', 'knew', 'patriotism', 'forgotten', 'truth', 'things', 'reminded', 'fathers', 'hearts']
#
#
# Discourse_Atom 2
# ['house', 'supremacist', 'collar', 'party', 'democrats', 'republican', 'congress', 'independents', 'houses', 'summaries', 'democratic', 'partisan', 'ryan', 'opponent', 'disappear', 'compromise', 'slogan', 'culmination', 'opposition', 'black', 'republicans', 'skip', 'cynical', 'mckeon', 'negotiators']
#
#
# Discourse_Atom 3
# ['essential', 'tools', 'maintain', 'strengthen', 'effectively', 'necessary', 'adequate', 'enable', 'securing', 'tool', 'goals', 'build', 'adequately', 'flexibility', 'urgently', 'resources', 'needed', 'effective', 'realistic', 'equip', 'implement', 'achieve', 'enhance', 'indispensable', 'sustainable']
#
#
# Discourse_Atom 4
# ['wealthy', 'pockets', 'breaks', 'wealthiest', 'aways', 'rich', 'penalized', 'dividend', 'giveaways', 'amt', 'expense', 'tax', 'gains', 'credits', 'millionaires', 'dividends', 'corporations', 'incomes', 'taxpayers', 'paying', 'capital', 'forcing', 'wealth', 'taxes', 'debts']
#
#
# Discourse_Atom 5
# ['dr', 'king', 'legacy', 'distinguished', 'martin', 'luther', 'kirk', 'library', 'mrs', 'crawford', 'scott', 'holsinger', 'celebrate', 'cameron', 'david', 'honoring', 'keroack', 'bob', 'profile', 'courage', 'truman', 'dedication', 'paul', 'principal', 'lance']
#
#
# Discourse_Atom 6
# ['undermine', 'integrity', 'defend', 'liberties', 'protected', 'legitimate', 'privacy', 'enforcing', 'constitutional', 'collective', 'exercise', 'uphold', 'fundamental', 'conventions', 'geneva', 'principles', 'responsibilities', 'enforce', 'governmental', 'balances', 'protecting', 'undermined', 'consistent', 'violates', 'ability']
#
#
# Discourse_Atom 7
# ['safety', 'protect', 'safe', 'table', 'miners', 'protecting', 'net', 'drug', 'food', 'americas', 'osha', 'pets', 'stamps', 'safeguard', 'protects', 'importation', 'prescription', 'keeping', 'plan', 'protection', 'calling', 'drugs', 'msha', 's', 'added']
#
#
# Discourse_Atom 8
# ['design', 'collaborative', 'statewide', 'navigation', 'habitat', 'restoration', 'conservation', 'construct', 'upgrades', 'ecosystem', 'ecological', 'recreation', 'rail', 'uw', 'laboratories', 'nantucket', 'partnerships', 'corridor', 'acquisition', 'yuma', 'poultry', 'resource', 'micro', 'commuter', 'engineering']
#
#
# Discourse_Atom 9
# ['deadline', 'military', 'withdrawal', 'redeployment', 'authorization', 'supported', 'resolution', 'authorize', 'escalation', 'combat', 'supplemental', 'uparmored', 'troops', 'voted', 'troop', 'pdbs', 'generals', 'opposition', 'timeline', 'opposed', 'withdrawing', 'insisted', 'courageously', 'supporting', 'authorized']
#
#
# Discourse_Atom 10
# ['attorney', 'surgeon', 'shinseki', 'petraeus', 'abizaid', 'adjutant', 'inspector', 'meyers', 'schoomaker', 'hayden', 'motors', 'solicitor', 'comptroller', 'attorneys', 'counsel', 'brigadier', 'lute', 'taguba', 'casey', 'odierno', 'maples', 'alberto', 'questioned', 'asked', 'conway']
#
#
# Discourse_Atom 11
# ['outer', 'textiles', 'tires', 'translated', 'geographic', 'kwhea', 'organizational', 'radar', 'downstream', 'conditioned', 'pest', 'exchanged', 'acquired', 'profiling', 'afb', 'evaluations', 'sludge', 'parcel', 'mhz', 'cruz', 'wabasha', 'thermal', 'journals', 'monitored', 'epidemiological']
#
#
# Discourse_Atom 12
# ['t', 'nt', 'simply', 'going', 'think', 'let', 'ticks', 'nice', 'tell', 'tried', 'games', 'll', 'talk', 'thermostat', 'irresponsible', 'willing', 'straight', 'apparently', 'sit', 'frankly', 'exactly', 'answer', 'lot', 'saying', 'inescapable']
#
#
# Discourse_Atom 13
# ['views', 'arguments', 'ideological', 'judgment', 'philosophy', 'nominee', 'view', 'oath', 'argument', 'precedent', 'justices', 'mainstream', 'confirmed', 'activist', 'decided', 'nominees', 'confirm', 'precedents', 'deciding', 'fit', 'confirmation', 'boyle', 'dissenting', 'mukasey', 'wise']
#
#
# Discourse_Atom 14
# ['representing', 'stabilized', 'caps', 'gays', 'inflicting', 'neighboring', 'unavoidable', 'strapped', 'blue', 'localities', 'united', 'represent', 'gyns', 'democracies', 'stores', 'bangladesh', 'victories', 'absorb', 'dumping', 'removing', 'reimburse', 'participating', 'difficulty', 'alike', 'suing']
#
#
# Discourse_Atom 15
# ['hearings', 'questions', 'consideration', 'witnesses', 'carefully', 'relevant', 'committees', 'judiciary', 'confirmation', 'holding', 'panel', 'hearing', 'answers', 'considering', 'sincerely', 'discussion', 'legislative', 'fcc', 'discussions', 'testimony', 'consider', 'nomination', 'nominations', 'appreciate', 'inquiry']
#
#
# Discourse_Atom 16
# ['patient', 'physicians', 'doctors', 'preventive', 'patients', 'illnesses', 'medications', 'medical', 'physical', 'illness', 'treating', 'medicines', 'hospitals', 'uncompensated', 'expensive', 'prenatal', 'nursing', 'errors', 'computerized', 'chronic', 'provider', 'disease', 'treatment', 'vaccine', 'diseases']
#
#
# Discourse_Atom 17
# ['gas', 'oil', 'gasoline', 'greenhouse', 'prices', 'fuels', 'dependence', 'emissions', 'producing', 'liquefied', 'ethanol', 'tank', 'pump', 'gases', 'fuel', 'coal', 'fossil', 'electricity', 'cartels', 'price', 'profits', 'tanks', 'skyrocketing', 'sources', 'supply']
#
#
# Discourse_Atom 18
# ['tucson', 'diego', 'miles', 'southern', 'san', 'flows', 'near', 'fencing', 'southwest', 'border', 'river', 'apprehended', 'blues', 'tribune', 'rio', 'fence', 'crossings', 'mexicans', 'blackstone', 'airports', 'crossing', 'mississippi', 'sanity', 'arizona', 'az']
#
#
# Discourse_Atom 19
# ['clearances', 'homeland', 'port', 'garrisoned', 'social', 'backup', 'breaches', 'lengthens', 'border', 'hardware', 'bioterrorism', 'perimeter', 'enhances', 'functions', 'retirement', 'structure', 'seaport', 'checks', 'ports', 'upswing', 'concealing', 'forces', 'reintegrate', 'dhs', 'demobilize']
#
#
# Discourse_Atom 20
# ['appeals', 'appellate', 'ruled', 'opinions', 'dissented', 'courts', 'cases', 'justices', 'circuit', 'trial', 'case', 'ruling', 'jury', 'judges', 'plaintiffs', 'habeas', 'proceedings', 'court', 'narrow', 'boyle', 'appeal', 'statutes', 'precedent', 'upheld', 'sentencing']
#
#
# Discourse_Atom 21
# ['fulfill', 'equality', 'values', 'americas', 'prosperity', 'reflect', 'greater', 'reaffirm', 'fulfilling', 'ensuring', 'truly', 'greatest', 'depends', 'stronger', 'achieving', 'moral', 'genuine', 'shared', 'safeguard', 'preserving', 'strengthening', 'protecting', 'importantly', 'democracy', 'fairer']
#
#
# Discourse_Atom 22
# ['women', 'men', 'divorced', 'uniform', 'servicemen', 'pregnant', 'minorities', 'brave', 'dignity', 'slurs', 'womens', 'reproductive', 'treated', 'color', 'nurses', 'everyday', 'singled', 'caregivers', 'disproportionately', 'married', 'mothers', 'sacrifices', 'racial', 'couples', 'naked']
#
#
# Discourse_Atom 23
# ['dropped', 'schip', 'uninsured', 'enrollment', 'shortfall', 'medicaid', 'cut', 'covered', 'enrolled', 'actuary', 'chip', 'decrease', 'underinsured', 'enroll', 'shortfalls', 'cover', 'socialized', 'slashes', 'eliminated', 'drastic', 'physician', 'wic', 'expansions', 'projected', 'cuts']
#
#
# Discourse_Atom 24
# ['department', 'departments', 'secretary', 'secretaries', 'byrne', 'bureau', 'connor', 'statistics', 'owen', 'jag', 'matteo', 'elaine', 'breyer', 'hhs', 'cjs', 'chief', 'undersecretary', 'rehnquist', 'juvenile', 'epa', 'obstruction', 'dot', 'agency', 'condoleezza', 'audits']
#
#
# Discourse_Atom 25
# ['wiretapping', 'relied', 'unconstitutional', 'decree', 'strip', 'rejected', 'explicitly', 'rubber', 'motions', 'sentencing', 'suit', 'controversial', 'filed', 'statutes', 'unwarranted', 'ruled', 'argued', 'intentionally', 'interpretations', 'overturn', 'interpretation', 'contrary', 'prohibition', 'eavesdropping', 'lobbyist']
#
#
# Discourse_Atom 26
# ['immediate', 'release', 'darkness', 'captives', 'delivery', 'triggering', 'press', 'curtail', 'sheet', 'prepared', 'quick', 'attention', 'calling', 'burner', 'delivered', 'relatives', 'phone', 'frustrating', 'emphasizing', 'aung', 'apology', 'embargoed', 'event', 'aclu', 'introduction']
#
#
# Discourse_Atom 27
# ['wasn', 'didn', 'wouldn', 'hasn', 'weren', 'hadn', 'aren', 'don', 'shouldn', 'doesn', 'haven', 'couldn', 'isn', 'won', 'sprint', 'pretending', 'valiant', 'complacent', 'fumes', 'att', 'cooking', 'fool', 'crazy', 'offs', 'refuse']
#
#
# Discourse_Atom 28
# ['achieve', 'accomplish', 'stronger', 'fulfill', 'common', 'genuine', 'realistic', 'closer', 'understand', 'ways', 'gain', 'achieving', 'goals', 'reach', 'chance', 'goal', 'recognize', 'sense', 'build', 'fail', 'find', 'solutions', 'compromises', 'play', 'importantly']
#
#
# Discourse_Atom 29
# ['perkins', 'recipients', 'pell', 'grants', 'grant', 'forgiveness', 'borrowing', 'borrowers', 'matching', 'maximum', 'nclb', 'reciprocity', 'gear', 'subsidized', 'trio', 'extension', 'banks', 'waiver', 'installment', 'funded', 'voucher', 'scholarships', 'program', 'loans', 'incentive']
#
#
# Discourse_Atom 30
# ['law', 'laws', 'blunt', 'rules', 'statute', 'statutes', 'worksite', 'immigrations', 'regulations', 'courts', 'affirming', 'judges', 'soundly', 'appeals', 'decree', 'legislature', 'precedent', 'actions', 'petitions', 'customs', 'constitution', 'comply', 'narrow', 'judgeship', 'procedure']
#
#
# Discourse_Atom 31
# ['tribal', 'local', 'concealed', 'outside', 'marana', 'landowners', 'rico', 'revoke', 'populous', 'locate', 'winona', 'assisting', 'situations', 'correctional', 'reservation', 'locations', 'northwestern', 'volunteerism', 'governments', 'detained', 'narco', 'coakley', 'ngos', 'kabul', 'pawlenty']
#
#
# Discourse_Atom 32
# ['working', 'work', 'worked', 'earned', 'works', 'insure', 'healthy', 'workplaces', 'struggling', 'giving', 'helping', 'educate', 'hearted', 'serve', 'earn', 'choose', 'hardworking', 'welfare', 'sure', 'sick', 'contribute', 'decent', 'neediest', 'poor', 'count']
#
#
# Discourse_Atom 33
# ['regulate', 'advertising', 'product', 'sale', 'patent', 'misconduct', 'brand', 'tobacco', 'biosimilar', 'marketing', 'cosmetic', 'abusive', 'practices', 'products', 'cigarettes', 'liability', 'retailers', 'deceptive', 'willful', 'potency', 'dtc', 'currencies', 'telecommunications', 'lull', 'manufacturer']
#
#
# Discourse_Atom 34
# ['rise', 'rising', 'stagnant', 'lowest', 'grown', 'quarter', 'gallon', 'productivity', 'risen', 'lowering', 'inflation', 'foreclosures', 'tank', 'rate', 'tenths', 'turnover', 'skyrocketing', 'dividends', 'hog', 'fastest', 'temperatures', 'decline', 'dramatically', 'gasoline', 'average']
#
#
# Discourse_Atom 35
# ['infectious', 'treating', 'symptoms', 'impairment', 'hiv', 'contaminated', 'outbreaks', 'pathogens', 'trace', 'brain', 'foodborne', 'arthritis', 'diagnoses', 'groundwater', 'cancers', 'potentially', 'alcohol', 'poisoning', 'accidents', 'diagnose', 'sewage', 'chemicals', 'cardiovascular', 'antiviral', 'trauma']
#
#
# Discourse_Atom 36
# ['sox', 'colorado', 'prize', 'rockies', 'republic', 'north', 'italian', 'south', 'virginia', 'abraham', 'visited', 'famous', 'arthur', 'grace', 'wall', 'paul', 'ireland', 'kentucky', 'celebrated', 'hall', 'nobel', 'lewis', 'gerry', 'trip', 'hill']
#
#
# Discourse_Atom 37
# ['worry', 'millions', 'getting', 'saved', 'choices', 'gets', 'wondering', 'misfortune', 'difference', 'save', 'precious', 'struggling', 'sick', 'losing', 'countless', 'squander', 'everyday', 'mothers', 'depend', 'healthy', 'dreams', 'essentials', 'hardworking', 'owe', 'healthier']
#
#
# Discourse_Atom 38
# ['care', 'insurance', 'healthcare', 'mental', 'childrens', 'coverage', 'enormity', 'disparities', 'dimock', 'professionals', 'maternal', 'benefits', 'public', 'happiness', 'affordable', 'reauthorizations', 'problems', 'miracles', 'hospitals', 'unsubstantiated', 'pensions', 'caring', 'better', 'accounts', 'priorities']
#
#
# Discourse_Atom 39
# ['leahy', 'chuck', 'sanders', 'menendez', 'dorgan', 'brownback', 'bailey', 'baucus', 'arlen', 'graham', 'vt', 'olympia', 'kay', 'wyden', 'lieberman', 'cantwell', 'boxer', 'obama', 'mikulski', 'biden', 'byron', 'lott', 'harkin', 'isakson', 'carper']
#
#
# Discourse_Atom 40
# ['past', 'short', 'takes', 'long', 'period', 'ahead', 'ago', 'overdue', 'later', 'changed', 've', 'waited', 'wait', 'coming', 'end', 'enactment', 'promises', 'correct', 'beginning', 'months', 'point', 'aside', 'taken', 'preceding', 'finally']
#
#
# Discourse_Atom 41
# ['balance', 'violates', 'reasonable', 'fairness', 'protections', 'uphold', 'fair', 'principle', 'procedural', 'remedy', 'fundamental', 'intent', 'vigorously', 'upholding', 'decide', 'practical', 'remedies', 'antitrust', 'constitutional', 'respects', 'impartial', 'enforce', 'correct', 'enforceable', 'cafta']
#
#
# Discourse_Atom 42
# ['u', 'america', 'nation', 'buys', 'nonsense', 'u.s', 'takeover', 'caf', 'predicts', 'depressing', 'gratifying', 'traced', 'everybody', 'lion', 'reintroducing', 'ideally', 'anti', 'somewhat', 'peru', 'tankfuls', 'restraining', 'guest', 'territorial', 'chaplain', 'farmworker']
#
#
# Discourse_Atom 43
# ['security', 'relations', 'oceanic', 'medpac', 'aging', 'involvements', 'archives', 'priority', 'interest', 'examine', 'key', 'subcommittee', 'oversight', 'atmospheric', 'committee', 'resolving', 'finance', 'selections', 'inadequacy', 'consider', 'envisioned', 'joint', 'stakeholders', 'embarrassment', 'proposals']
#
#
# Discourse_Atom 44
# ['efficiently', 'cycle', 'shifting', 'viable', 'lessen', 'selling', 'undue', 'dependency', 'shifted', 'alleviating', 'decreasing', 'leveling', 'commensurate', 'lawfully', 'occurring', 'targets', 'grossly', 'ease', 'hugely', 'tasks', 'type', 'relieve', 'metric', 'assign', 'burdensome']
#
#
# Discourse_Atom 45
# ['establishing', 'performance', 'assessments', 'highly', 'multilateral', 'instruction', 'advanced', 'reading', 'sustainable', 'standards', 'strategies', 'collaboration', 'developing', 'developed', 'rigorous', 'engineering', 'effectiveness', 'facilitate', 'creates', 'curriculum', 'technology', 'preparation', 'promotes', 'conservation', 'efficient']
#
#
# Discourse_Atom 46
# ['washington', 'snipers', 'c', 'nwwashington', 'ph', 'wi', 'calif', 'press', 'nd', 'dirksen', 'conn', 'mich', 'nw', 'senior', 'mass', 'sw', 'minn', 'avenue', 'rob', 'ark', 'hawaii', 'fla', '2633washington', '60s', 'hosting']
#
#
# Discourse_Atom 47
# ['guidance', 'oversight', 'compliance', 'specific', 'requiring', 'authority', 'reviews', 'expedite', 'implementation', 'guidelines', 'comply', 'evaluate', 'procedures', 'regulatory', 'waive', 'mechanisms', 'criteria', 'regulation', 'implement', 'foia', 'modify', 'investigate', 'implementing', 'submit', 'reorganization']
#
#
# Discourse_Atom 48
# ['retain', 'hire', 'employers', 'illegally', 'unscrupulous', 'employ', 'immigrant', 'seeking', 'undocumented', 'guestworkers', 'unions', 'organize', 'hiring', 'legally', 'employees', 'outsourcing', 'status', 'retirees', 'backgrounds', 'dependent', 'shadows', 'individuals', 'redress', 'permanent', 'incarcerating']
#
#
# Discourse_Atom 49
# ['strongly', 'resonates', 'reauthorizing', 'slogan', 'holidays', 'applaud', 'renew', 'supporters', 'declare', 'garner', 'apologize', 'resounding', 'schoolchildren', 'thanked', 'bicameral', 'excel', 'mckeon', 'kidsfirst', 'urge', 'thankfully', 'eminently', 'support', 'priest', 'laud', 'responsibly']
#
#
# Discourse_Atom 50
# ['colleagues', 'delegation', 'pleased', 'pleasure', 'bipartisan', 'klobuchar', 'aisle', 'hopeful', 'enzi', 'bicameral', 'applaud', 'tirelessly', 'welcome', 'commend', 'thank', 'appreciate', 'grateful', 'join', 'forward', 'tireless', 'group', 'closely', 'sides', 'realizes', 'panelists']
#
#
# Discourse_Atom 51
# ['corps', 'expeditionary', 'army', 'humvees', 'armored', 'base', 'marine', 'units', 'baghdad', 'pentagon', 'vehicles', 'marines', 'humvee', 'unit', 'warned', 'command', 'estimate', 'brigades', 'infantry', 'operations', 'space', 'pilots', 'deployed', 'container', 'kit']
#
#
# Discourse_Atom 52
# ['states', 'steelworkers', 'emirates', 'methodist', 'nations', 'cerebral', 'palsy', 'kingdom', 'auto', 'qatar', 'rebels', 'defraud', 'nationals', 'crashed', 'countries', 'arc', 'plumbing', 'aliens', 'parish', 'percent', 'refugee', 'enter', 'canada', 'telephones', 'u.s']
#
#
# Discourse_Atom 53
# ['jobs', 'farmers', 'economy', 'growth', 'workforce', 'investment', 'contribute', 'value', 'compete', 'businesses', 'wages', 'sectors', 'retain', 'investing', 'opportunities', 'ranchers', 'dairy', 'industries', 'firms', 'heavily', 'overseas', 'economies', 'productivity', 'job', 'sector']
#
#
# Discourse_Atom 54
# ['act', 'strengthen', 'national', 'strengthens', 'strengthening', 'key', 'bioterrorism', 'enhances', 'structure', 'paa', 'component', 'pronged', 'upholds', 'pledging', 'augment', 'restore', 'guarantees', 'preparedness', 'enforcing', 'addresses', 'consistent', 'modernize', 'comprehensive', 'weakened', 'transparency']
#
#
# Discourse_Atom 55
# ['soldiers', 'troops', 'soldier', 'unarmored', 'deployment', 'deployments', 'casualties', 'tours', 'wounded', 'combat', 'humvee', 'armor', 'deployed', 'diyala', 'brigade', 'unprotected', 'troop', 'dumpsters', 'plates', 'afghanistan', 'humvees', 'withdrawal', 'province', 'heros', 'withdrawing']
#
#
# Discourse_Atom 56
# ['england', 'hampshire', 'orleans', 'frontier', 'bedford', 'york', 'era', 'century', 'mexico', 'generation', 'technologies', 'jersey', 'building', 'create', 'creating', 'hampton', 'rankings', 'entrants', 'ideas', 'built', 'dynamic', 'innovative', 'direction', 'cures', 'globalization']
#
#
# Discourse_Atom 57
# ['fy', 'funding', 'extension', 'supplemental', 'grant', 'budget', 'funds', 'omnibus', 'block', 'liheap', 'appropriations', 'included', 'projects', 'appropriation', 'fy2006', 'appropriating', 'appropriated', 'proposed', 'addition', 'authorization', 'contains', 'includes', 'allocated', 'fy06', 'initiatives']
#
#
# Discourse_Atom 58
# ['county', 'michigan', 'northeastern', 'missouri', 'orange', 'club', 'alliance', 'worcester', 'st', 'springfield', 'west', 'essex', 'island', 'brockton', 'rhode', 'polytechnic', 'maine', 'dakota', 'illinois', 'pennsylvania', 'town', 'louis', 'lawrence', 'florida', 'psychological']
#
#
# Discourse_Atom 59
# ['amendments', 'passage', 'adopted', 'passed', 'provision', 'passes', 'measure', 'contains', 'pass', 'sponsors', 'introduced', 'provisions', 'bi', 'sponsor', 'original', 'debated', 'offered', 'enacting', 'h.r', 'overwhelmingly', 'version', 'reauthorization', 'expiring', 'reauthorize', 'introduce']
#
#
# Discourse_Atom 60
# ['new', 'mccain', 'change', 'proposing', 'pledging', 'madness', 'deadline', 'paves', 'introduce', 'reverse', 'push', 'kerry', 'secure', 'beginning', 'kerrys', 'accomplish', 'cornyn', 'strategy', 'encouraged', 'redeploy', 'gregg', 'orderly', 'optimistic', 'redeployment', 'introducing']
#
#
# Discourse_Atom 61
# ['borrowers', 'loans', 'lenders', 'forgiveness', 'banks', 'student', 'loan', 'colleges', 'lending', 'forgiven', 'scholarships', 'debt', 'borrower', 'sheltered', 'lender', 'borrowing', 'students', 'subsidies', 'credit', 'college', 'degree', 'preferred', 'mortgage', 'gifts', 'aid']
#
#
# Discourse_Atom 62
# ['excerpts', 'capka', 'praised', 'praising', 'applauded', 'inquired', 'thanked', 'asks', 'wausau', 'monday', 'arthurs', 'britt', 'pointed', 'frists', 'remarks', 'friday', 'note', 'commented', 'pdb', 'delivered', 'paulison', 'click', 'reiterated', 'sworn', 'thursday']
#
#
# Discourse_Atom 63
# ['vice', 'bushs', 'nixon', 'gerald', 'ford', 'roosevelt', 'reagan', 'lyndon', 'bush', 'eisenhower', 'musharraf', 'assad', 'karzai', 'travaglini', 'mahmoud', 'dwight', 'mr', 'bounds', 'nominate', 'johnson', 'directive', 'disapprove', 'rebuke', 'inaugural', 'lobbied']
#
#
# Discourse_Atom 64
# ['request', 'proposal', 'budget', 'declaration', 'proposed', 'urge', 'siphoning', 'proposals', 'fema', 'emergency', 'letter', 'decision', 'reconsider', 'contingency', 'liheap', 'funds', 'priorities', 'sba', 'response', 'immediately', 'soon', 'disaster', 'usda', 'respectfully', 'disappointed']
#
#
# Discourse_Atom 65
# ['years', 'weeks', 'months', 'decade', 'decades', 'year', 'days', 'half', 'learned', 'summer', 'later', 'month', 'spring', 'times', 'mayflower', 'seen', 'period', 'tripled', 've', 'time', 'fashioned', 'preceding', 'changed', 'nearly', 'ago']
#
#
# Discourse_Atom 66
# ['services', 'visits', 'centers', 'vet', 'medicaid', 'covered', 'outreach', 'readjustment', 'items', 'counseling', 'hhs', 'outpatient', 'afterschool', 'va', 'nutrition', 'schip', 'dimock', 'veterans', 'rehabilitation', 'shelter', 'uncompensated', 'managed', 'cms', 'enroll', 'reimbursement']
#
#
# Discourse_Atom 67
# ['questions', 'asked', 'ask', 'asking', 'answers', 'unanswered', 'matter', 'gonzales', 'testimony', 'alito', 'question', 'myers', 'nominee', 'raises', 'told', 'views', 'judge', 'confirmation', 'opinion', 'case', 'mukasey', 'view', 'mr', 'answer', 'nomination']
#
#
# Discourse_Atom 68
# ['reductions', 'projected', 'decrease', 'significantly', 'annually', 'double', 'inflation', 'exceed', 'roughly', 'resulting', 'increased', 'risen', 'adjusted', 'foreclosures', 'expenditures', 'resulted', 'total', 'combined', 'decreased', 'dramatically', 'equivalent', 'reduced', 'gallons', 'estimated', 'adjusting']
#
#
# Discourse_Atom 69
# ['fishermen', 'devastated', 'floods', 'flooding', 'gulf', 'rebuilding', 'hurricanes', 'disaster', 'katrina', 'rebuild', 'shellfishermen', 'tide', 'bridge', 'coastal', 'residents', 'damaged', 'recovery', 'storms', 'affected', 'rita', 'hurricane', 'uxbridge', '35w', 'fishing', 'recover']
#
#
# Discourse_Atom 70
# ['active', 'duty', 'deployed', 'tours', 'reservists', 'members', 'wounded', 'demobilized', 'marines', 'reservist', 'retired', 'guardsmen', 'brigade', 'reserve', 'returning', 'infantry', 'service', 'jimenez', 'guardsman', 'deployments', 'officers', 'length', 'airmen', 'mobilized', 'medals']
#
#
# Discourse_Atom 71
# ['charles', 'j', 'bernard', 'akaka', 'evan', 'tim', 'susan', 'barbara', 'murkowski', 'max', 'christopher', 'maria', 'bingaman', 'joseph', 'gordon', 'daniel', 'lisa', 'mary', 'barney', 'jeff', 'carl', 'ken', 'richard', 'tester', 'lautenberg']
#
#
# Discourse_Atom 72
# ['committee', 'committees', 'senate', 'subcommittees', 'senates', 'subcommittee', 'ranking', 'judiciary', 'unanimously', 'unanimous', 'testify', 'testimony', 'chaplain', 'scarring', 'miaoulis', 'hearing', 'lungs', 'panel', 'analogous', 'hearings', 'witnesses', 'democrat', 'cjs', 'overwhelmingly', 'armed']
#
#
# Discourse_Atom 73
# ['workers', 'immigrants', 'citizens', 'illegally', 'refugees', 'deport', 'translator', 'forces', 'iraqis', 'latin', 'abroad', 'countries', 'civilians', 'resettle', 'nationals', 'immigrant', 'persons', 'translators', 'legally', 'shadows', 'groups', 'population', 'undocumented', 'hmong', 'vast']
#
#
# Discourse_Atom 74
# ['congress', 'policies', 'government', 'failures', 'policy', 'asserted', 'moral', 'vindicate', 'matters', 'confidence', 'criticism', 'touch', 'scandalous', 'failure', 'failing', 'unilateral', 'inescapable', 'refuses', 'critics', 'ignored', 'signal', 'indication', 'reassure', 'misplaced', 'exercise']
#
#
# Discourse_Atom 75
# ['automatically', 'covered', 'payments', 'premium', 'expenses', 'forced', 'enrollees', 'overtime', 'differential', 'insured', 'paid', 'eligible', 'buy', 'pocket', 'payment', 'cover', 'spouses', 'salary', 'sbp', 'enroll', 'extra', 'qualifying', 'cash', 'currently', 'fees']
#
#
# Discourse_Atom 76
# ['war', 'soldiers', 'afghanistan', 'battle', 'returning', 'wounded', 'unarmored', 'troops', 'wars', 'brave', 'heroes', 'returned', 'surge', 'vietnam', 'veterans', 'mission', 'veteran', 'tours', 'insurgency', 'sacrifice', 'ultimate', 'combat', 'baghdad', 'victory', 'soldier']
#
#
# Discourse_Atom 77
# ['business', 'small', 'owners', 'motorboat', 'medium', 'businesses', 'subset', 'sized', 'affiliation', 'owned', 'incubator', 'sba', 'sehbp', 'jcedc', 'establishments', 'entrepreneurship', 'usual', 'farms', 'private', 'portion', 'firms', 'occupation', 'investors', 'manufacturers', 'truckers']
#
#
# Discourse_Atom 78
# ['scheduled', 'follows', 'urging', 'version', 'monday', 'july', 'unanimously', 'agreed', 'december', 'pdf', 'tuesday', 'text', 'earmarks', 'duck', 'november', 'attached', 'dni', 'copy', 'motion', 'signatures', 'attaching', 'february', 'unanimous', 'letter', 'thursday']
#
#
# Discourse_Atom 79
# ['path', 'borders', 'border', 'undocumented', 'immigrants', 'visa', 'fences', 'residence', 'status', 'calderon', 'quo', 'temporary', 'amnesty', 'visas', 'worker', 'ports', 'adjust', 'shadows', 'permanent', 'legalization', 'citizenship', 'terrorists', 'illegal', 'realities', 'immigration']
#
#
# Discourse_Atom 80
# ['federal', 'accountability', 'partner', 'maximize', 'guaranty', 'assesses', 'private', 'awarding', 'edited', 'contracting', 'branches', 'manuals', 'direct', 'bids', 'commitments', 'overall', 'retreats', 'lacked', 'self', 'offshoring', 'similarly', 'agencies', 'departments', 'partnering', 'accounting']
#
#
# Discourse_Atom 81
# ['forever', 'alive', 'courage', 'inspiration', 'reminded', 'compassion', 'moment', 'achievements', 'inspire', 'tradition', 'legacy', 'inspired', 'pride', 'passion', 'eloquent', 'spirit', 'hopes', 'inspiring', 'minds', 'dreams', 'stood', 'incredible', 'watching', 'conscience', 'love']
#
#
# Discourse_Atom 82
# ['following', 'statement', 'released', 'issued', 'labor', 'txu', 'report', 'treasury', 'announced', 'pension', 'pensions', 'response', 'spending', 'includes', 'today', 'recognizance', 'edward', 'statistics', 'changes', 'hhs', 'approved', 'transportation', 'consider', 'provision', 'sheet']
#
#
# Discourse_Atom 83
# ['information', 'pandemic', 'response', 'emergency', 'publicly', 'records', 'preparedness', 'requests', 'feedback', 'detailed', 'cdc', 'request', 'analysis', 'document', 'humanitarian', 'ocr', 'database', 'management', 'disbursement', 'transmission', 'data', 'documents', 'communications', 'electronic', 'concerning']
#
#
# Discourse_Atom 84
# ['sincerely', 'consideration', 'sssa', 'fsa', 'respectfully', 'request', 'prompt', 'feedback', 'conjunctively', 'garner', 'disjunctively', 'responses', 'scot', 'deemed', 'possible', 'soon', 'andrew', 'website', 'promptly', 'http', 'documents', 'discussing', 'offices', 'appreciate', 'www']
#
#
# Discourse_Atom 85
# ['acknowledged', 'karl', 'questioned', 'rove', 'alberto', 'comments', 'architect', 'presided', 'gonzales', 'resignation', 'adviser', 'appoint', 'advisor', 'explained', 'addington', 'stated', 'stating', 'express', 'haynes', 'influenced', 'criticizing', 'acting', 'nominated', 'plainly', 'banker']
#
#
# Discourse_Atom 86
# ['term', 'overdue', 'awaited', 'latency', 'standing', 'waited', 'run', 'time', 'surveying', 'past', 'far', 've', 'ago', 'way', 'short', 'ahead', 'unemployable', 'squabbling', 'louisianans', 'tidal', 'takes', 'lasting', 'pages', 'certainty', 'crapo']
#
#
# Discourse_Atom 87
# ['wagoner', 'burton', 'montrey', 'wilder', 'maley', 'keith', '202/', 'carney', 'andrew', 'patmintra', 'melissa', 'scot', 'capps', 'ryan', 'leonard', 'inflammatory', 'drafts', 'orfield', 'strips', 'strictly', 'schwartz', 'papers', 'reflecting', 'witness', 'conyers']
#
#
# Discourse_Atom 88
# ['assistant', 'deputy', 'officer', 'affairs', 'nwwashington', 'official', 'police', 'education400', 'powell', 'condoleezza', 'general', 'division', 'geren', 'commander', 'attorney', 'chief', 'chiefs', 'blum', 'aguilar', 'county', 'colin', 'avenue', 'prosecutor', 'inspector', 'hennepin']
#
#
# Discourse_Atom 89
# ['yesterday', 'general', 'intention', 'generals', 'friday', 'allawi', 'kennedy', 'asking', 'dni', 'intends', 'madness', 'november', 'stunning', 'anticipation', 'unanswered', 'loud', 'february', 'pledged', 'shrift', 'matches', 'report', 'gop', 'gao', 'tally', 'december']
#
#
# Discourse_Atom 90
# ['approach', 'comprehensive', 'solution', 'problems', 'problem', 'reform', 'solutions', 'plan', 'deal', 'broken', 'address', 'crisis', 'solve', 'fix', 'strategy', 'realistic', 'immigration', 'system', 'sense', 'reforms', 'complex', 'real', 'sensible', 'urgent', 'common']
#
#
# Discourse_Atom 91
# ['issues', 'issue', 'pressing', 'addressed', 'addressing', 'discussion', 'complex', 'bipartisanship', 'elicit', 'complicated', 'aspect', 'decency', 'solve', 'highlighted', 'sticker', 'resolved', 'present', 'thinking', 'thoughtful', 'triumphed', 'sense', 'correcting', 'underscored', 'pushing', 'profound']
#
#
# Discourse_Atom 92
# ['honored', 'bobby', 'honoring', 'mrs', 'friend', 'tsongas', 'ceremony', 'celebrate', 'bob', 'brother', 'dan', 'profile', 'paul', 'robinson', 'jackie', 'wellstone', 'wonderful', 'scott', 'congratulate', 'father', 'hall', 'memory', 'king', 'lewis', 'menino']
#
#
# Discourse_Atom 93
# ['sex', 'miranda', 'voting', 'marriage', 'section', 'clone', 'offender', 'rights', 'ix', 'title', 'machines', 'p.l', 'religious', 'liberties', 'amends', 'disobedience', 'hipaa', 'aclu', 'discriminatory', 'irregularities', 'duke', 'violated', 'victim', 'prohibiting', 'bilingual']
#
#
# Discourse_Atom 94
# ['state', 'local', 'governments', 'agencies', 'district', 'revoke', 'legislatures', 'officials', 'countable', 'level', 'declaration', 'emergency', 'assistance', 'discretion', 'federal', 'assist', 'matching', 'police', 'counties', 'massachusetts', 'traditionally', 'columbia', 'disaster', 'agency', 'western']
#
#
# Discourse_Atom 95
# ['liheap', 'dollars', 'receive', 'taxpayer', 'thousands', 'receiving', 'spent', 'billions', 'hundreds', 'cut', 'eligible', 'approximately', 'estimated', 'extended', 'received', 'slashes', 'pell', 'spend', 'millionaire', 'recipients', 'tens', 'cents', 'millionaires', 'needy', 'additional']
#
#
# Discourse_Atom 96
# ['hearing', 'witnesses', 'testified', 'discuss', 'convened', 'jec', 'testimony', 'friday', 'findings', 'panel', 'conference', 'scheduling', 'holding', 'meeting', 'session', 'highlighted', 'meetings', 'questionnaire', 'thursday', 'chaired', 'banking', 'wednesday', 'urged', 'hearings', 'intergovernmental']
#
#
# Discourse_Atom 97
# ['highest', 'ability', 'share', 'decisions', 'particularly', 'citizens', 'history', 'race', 'burden', 'power', 'values', 'job', 'compete', 'enormous', 'bidder', 'invested', 'greatest', 'society', 'powerful', 'impact', 'regardless', 'consumers', 'private', 'rights', 'slowing']
#
#
# Discourse_Atom 98
# ['tirelessly', 'yes', 'hard', 'hopeful', 'eloquently', 'thankful', 'insurgencies', 'skillfully', 'aisle', 've', 'revive', 'sides', 'tally', 'happy', 'tireless', 'voices', 'adams', 'divisional', 'colleagues', 'lasting', 'diplomatically', 'excited', 'fortunate', 'hopefully', 'recommit']
#
#
# Discourse_Atom 99
# ['families', 'people', 'citizens', 'family', 'parents', 'disabled', 'count', 'legislators', 'desperately', 'neighbor', 'kids', 'dream', 'refugees', 'strengthened', 'actively', 'constituents', 'birthright', 'elderly', 'poor', 'seniors', 'impoverished', 'solemn', 'caring', 'wrap', 'persons']
#
#
# Discourse_Atom 100
# ['americans', 'society', 'people', 'servicemembers', 'citizens', 'freedom', 'freedoms', 'human', 'beings', 'warriors', 'peoples', 'dream', 'bedrock', 'schoolhouse', 'unshakable', 'epic', 'happiness', 'race', 'equality', 'resilient', 'touches', 'defense', 'values', 'elders', 'greatest']
#
#
# Discourse_Atom 101
# ['drug', 'drugs', 'generic', 'prescription', 'importation', 'discounts', 'prescribe', 'user', 'negotiating', 'advertising', 'pet', 'formularies', 'medicines', 'vioxx', 'medicare', 'pantries', 'medications', 'labeling', 'sale', 'payoffs', 'products', 'toys', 'beneficiaries', 'hmos', 'biologics']
#
#
# Discourse_Atom 102
# ['bernice', 'whitewater', 'malone', 'valerie', 'lone', 'rendell', 'taoiseach', 'jianli', 'anderson', 'ann', 'ian', 'dunk', 'fervor', 'serial', 'paisley', 'yang', 'hitler', 'occasion', 'steenland', 'viciously', 'ft', 'contacted', 'vick', 'hijacker', 'beckett']
#
#
# Discourse_Atom 103
# ['employer', 'employers', 'worker', 'contract', 'temporary', 'hiring', 'employee', 'employees', 'fines', 'overtime', 'defined', 'employment', '1b', '2b', 'mandatory', 'exemption', 'misclassification', 'pension', 'voluntary', 'adjustment', 'verification', 'exempt', 'verify', 'portability', 'visa']
#
#
# Discourse_Atom 104
# ['conservancy', 'historical', 'landscape', 'advancement', 'stewardship', 'alliances', 'consortium', 'ethic', 'secular', 'catholic', 'sanctuary', 'ministries', 'backbone', 'defamation', 'interfaith', 'formed', 'linked', 'treasure', 'assabet', 'pacific', 'league', 'baptist', 'jesuit', 'seiu', 'culturally']
#
#
# Discourse_Atom 105
# ['d', 'dc', 'reiss', 'post', 'dctoday', 'snap', 'oregon', 'alaska', 'c', 'u', 'shelton', 'announced', 'avenue', 'sanity', 'hyatt', 'john', 'mingle', 'capitol', 'nwwashington', 'noted', 'senior', 'joined', 'julia', 'jon', 'et']
#
#
# Discourse_Atom 106
# ['boston', 'trio', 'wpi', 'award', 'umass', 'springfield', 'massachusetts', 'billerica', 'awards', 'amherst', 'arts', 'mcla', 'm', 'proud', 'brockton', 'pleased', 'grant', 'lowell', 'edward', 'faculty', 'hillside', 'commonwealth', 'graduate', 'campus', 'citysquare']
#
#
# Discourse_Atom 107
# ['graduating', 'taught', 'teaches', 'talented', 'door', 'mount', 'trains', 'amazing', 'oldest', 'beloved', 'stars', 'opened', 'fenway', 'readers', 'abby', 'remarkable', 'music', 'beautiful', 'buddhist', 'somerset', 'attending', 'shining', 'celtics', 'campuses', 'undefeated']
#
#
# Discourse_Atom 108
# ['kyl', 'kerry', 'kohl', 'criminal', 'byrne', 'penalties', 'o', 'klobuchar', 'solomon', 'connor', 'crime', 'sticklers', 'protection', 'cap', 'kennedy', 'retraining', 'environmental', 'adjustment', 'purely', 'backlog', 'aliens', 'endowment', 'hancock', 'upholds', 'alien']
#
#
# Discourse_Atom 109
# ['contact', 'energy', 'come', 'dearest', 'works', 'great', 'vision', 'building', 'melissa', 'foster', 'dedication', 'revolution', 'rest', 'tech', 'love', 'extraordinary', 'unique', 'technology', 'natural', 'commend', 'cultural', 'thanks', 'modern', 'thank', 'generation']
#
#
# Discourse_Atom 110
# ['innocent', 'prejudice', 'racial', 'muslims', 'motivated', 'insensitivity', 'cleansing', 'horrible', 'accused', 'ethnic', 'victimized', 'intimidation', 'naked', 'bigotry', 'assault', 'dogs', 'religion', 'suspect', 'simulate', 'attacked', 'captured', 'sexual', 'marched', 'murder', 'gay']
#
#
# Discourse_Atom 111
# ['irresponsible', 'sadly', 'stubbornly', 'rhetoric', 'mistake', 'straight', 'worse', 'exactly', 'excuses', 'acknowledge', 'try', 'pretend', 'touch', 'wants', 'bit', 'reckless', 'clearer', 'accept', 'gotten', 'lets', 'stop', 'hollow', 'clings', 'sends', 'unfortunately']
#
#
# Discourse_Atom 112
# ['funds', 'funding', 'resources', 'assistance', 'efforts', 'reimbursements', 'effort', 'communities', 'desperately', 'responders', 'match', 'deliver', 'grants', 'declaration', 'commonsense', 'governments', 'support', 'programs', 'rebuild', 'flexibility', 'initiative', 'gear', 'firefighting', 'agencies', 'evacuees']
#
#
# Discourse_Atom 113
# ['sen', 'mccain', 'releases', 'senator', 'introduced', 'snowe', 'secure', 'introduce', 'sponsored', 'senators', 'orderly', 'jon', 'sens', 'legislacin', 'pledging', 'amendment', 'co', 'cosponsored', 'added', 'instrumental', 'secures', 'introducing', 'lauded', 'cosponsor', 'secured']
#
#
# Discourse_Atom 114
# ['s.', 'fingerprint', 'belt', 'boundary', 'revision', 'cienegas', 'sherman', 'star', 'abatement', 'enhancement', 'roadless', 'summary', 'miner', 'preservation', 'author', 'scenic', 'magnuson', 'banner', 'refuge', 'sun', 'p.l', 'modifies', 'aclu', 'tn', 'species']
#
#
# Discourse_Atom 115
# ['han', 'todos', 'razn', 'vidas', 'ellos', 'muy', 'pero', 'debemos', 'como', 'una', 'cuando', 'por', 'mundial', 'es', 'todas', 'hacerlo', 'iraques', 'sus', 'si', 'yo', 'tropas', 'estaban', 'propia', 'sobre', 'mensaje']
#
#
# Discourse_Atom 116
# ['looked', 'democrats', 'democratic', 'differences', 'partisan', 'persuade', 'republican', 'presidents', 'conclusion', 'signal', 'party', 'republicans', 'message', 'opposition', 'president', 'political', 'agree', 'consensus', 'heed', 'politics', 'parties', 'majority', 'insisted', 'negotiations', 'attempt']
#
#
# Discourse_Atom 117
# ['marked', 'careo', 'triumphs', 'ronald', 'pediatrician', 'pornographers', 'keroack', 'latest', 'pornography', 'clayton', 'patriot', 'intelligence', 'adolescent', 'left', 'udall', 'childhelp', 'misleading', 'floodgates', 'signs', 'enactment', 'reauthorized', 'aeronautics', 'disseminating', 'charted', 'veterinary']
#
#
# Discourse_Atom 118
# ['includes', 'contains', 'authorizes', 'expands', 'establishes', 'included', 'provides', 'summary', 'contained', 'omnibus', 'implements', 'combines', 'include', 'introduces', 'aims', 'approved', 'require', 'boost', 'reauthorize', 'requires', 'adopts', 'supports', 'improvement', 'enhancement', 'builds']
#
#
# Discourse_Atom 119
# ['daily', 'desert', 'toxins', 'famine', 'built', 'located', 'polling', 'bus', 'nearby', 'industrial', 'afflicted', 'vicinity', 'blood', 'suffered', 'places', 'ski', 'asia', 'roots', 'inner', 'psychological', 'newport', 'nebraska', 'southeast', 'nashua', 'shores']
#
#
# Discourse_Atom 120
# ['knowledge', 'learning', 'teachers', 'teacher', 'curriculum', 'academic', 'classroom', 'teaching', 'teach', 'skills', 'subjects', 'reading', 'schools', 'instruction', 'classrooms', 'succeed', 'literacy', 'elementary', 'math', 'courses', 'educators', 'achievement', 'principals', 'learn', 'childs']
#
#
# Discourse_Atom 121
# ['ensuring', 'improving', 'enhance', 'preserving', 'vital', 'indispensable', 'promoting', 'strengthening', 'preserve', 'improve', 'promote', 'strengthen', 'ensure', 'expanding', 'essential', 'aspects', 'strengthens', 'diverse', 'ensures', 'recreational', 'restore', 'maintaining', 'builds', 'supports', 'securely']
#
#
# Discourse_Atom 122
# ['american', 'choose', 'free', 'color', 'regardless', 'corporations', 'choosing', 'corporate', 'expense', 'vast', 'break', 'expect', 'ordinary', 'worth', 'driven', 'pockets', 'weak', 'rely', 'affect', 'bankrupt', 'choice', 'represent', 'willing', 'margins', 'non']
#
#
# Discourse_Atom 123
# ['escalation', 'terrorism', 'withdrawal', 'timetable', 'mission', 'surge', 'defeat', 'taliban', 'compromises', 'redeployment', 'timeline', 'conflict', 'sunni', 'insurgency', 'presence', 'troop', 'madness', 'diplomacy', 'iraqs', 'misguided', 'begin', 'horizon', 'strategy', 'pakistan', 'terror']
#
#
# Discourse_Atom 124
# ['extent', 'militias', 'equipped', 'personnel', 'conflict', 'survivability', 'operations', 'units', 'targeted', 'timetable', 'proper', 'civilian', 'fighters', 'presence', 'capabilities', 'disbanding', 'operating', 'officers', 'combat', 'taliban', 'ground', 'capable', 'consular', 'commitments', 'iraqs']
#
#
# Discourse_Atom 125
# ['high', 'today', 'week', 'century', 'caf', 'todays', 'industrialized', 'stakes', 'point', 'leadership', 'demand', 'reluctance', 'reaching', 'points', 'challenge', 'bali', 'talking', 'succeed', 'straight', 'disappear', 'dropouts', 'emphasize', 'cafe', 'challenges', 'ingenuity']
#
#
# Discourse_Atom 126
# ['osama', 'laden', 'bin', 'hussein', 'bomb', 'brutal', 'murderous', 'saddam', 'husseins', 'musab', 'extremists', 'gravest', 'blew', 'zarqawi', 'enders', 'qaida', 'attacked', 'egypt', 'israel', 'philippines', 'hezbollah', 'islamic', 'attack', 'anger', 'imminent']
#
#
# Discourse_Atom 127
# ['regional', 'commission', 'recommendations', 'capabilities', 'investigations', 'operations', 'structure', 'cooperation', 'specific', 'multilateral', 'agency', 'conducting', 'efforts', 'aviation', 'framework', 'assessment', 'establish', 'ongoing', 'elements', 'investigate', 'governing', 'preparedness', 'implementation', 'coordinated', 'agencys']
#
#
# Discourse_Atom 128
# ['c', 'mass', 'ph', 'subsection', 'wi', 'subtitle', 'snipers', 'fla', 'mn', 'wv', 'mont', 'calif', 'ma', 'nj', 'mich', 'conn', 'nd', 'washington', 'ri', 'n', 'minn', 'ark', 'hi', 'ne', 'donut']
#
#
# Discourse_Atom 129
# ['louisiana', 'toddlers', 'dropped', 'registered', 'approximately', 'percentage', 'households', 'displaced', 'thirds', 'homeless', 'surveyed', 'percent', 'totals', 'enrolled', 'hmong', 'scored', 'counties', 'infants', 'underrepresented', 'missouri', 'allowance', 'eligible', 'graders', 'erie', 'totaling']
#
#
# Discourse_Atom 130
# ['civil', 'human', 'freedoms', 'world', 'siege', 'easement', 'society', 'protecting', 'greatest', 'equality', 'dignity', 'equal', 'reemployment', 'fought', 'terror', 'immense', 'happiness', 'precious', 'proxy', 'movement', 'basic', 'sacrifices', 'cold', 'enjoy', 'peoples']
#
#
# Discourse_Atom 131
# ['asbestos', 'victims', 'silences', 'induced', 'seriously', 'compensate', 'exposure', 'treated', 'injured', 'recover', 'alleviate', 'compensation', 'severely', 'suffering', 'injury', 'disease', 'injuries', 'contamination', 'diseases', 'cancers', 'infectious', 'ill', 'prevented', 'damages', 'lung']
#
#
# Discourse_Atom 132
# ['enforcement', 'rule', 'current', 'baathification', 'signed', 'practiced', 'uva', 'abiding', 'facto', 'promised', 'enforce', 'enforcing', 'anti', 'changes', 'violation', 'broken', 'enacted', 'provincial', 'fullest', 'amnesty', 'changed', 'sign', 'enactment', 'signing', 'antitrust']
#
#
# Discourse_Atom 133
# ['child', 'providers', 'children', 'parents', 'populations', 'tutoring', 'patient', 'childhood', 'internet', 'adults', 'access', 'individuals', 'developmental', 'treatment', 'doctors', 'hospitals', 'professionals', 'prevention', 'behinds', 'mental', 'continuity', 'early', 'parent', 'classroom', 'literacy']
#
#
# Discourse_Atom 134
# ['fannie', 'totaling', 'accounted', 'holder', 'flights', 'utilities', 'gradually', 'boeing', 'allowance', 'roughly', 'interchange', 'parking', 'repayments', 'typically', 'thirds', 'installment', 'bonuses', 'ged', 'bonus', 'otms', 'lesser', 'surpassing', 'volume', 'holders', 'stagnated']
#
#
# Discourse_Atom 135
# ['commerce', 'subcommittee', 'finance', 'banking', 'judiciary', 'agriculture', 'appropriations', 'labor', 'treasury', 'relations', 'chairman', 'committee', 'member', 'hearing', 'aging', 'pensions', 'chair', 'testified', 'unanimously', 'txu', 'chamber', 'democrat', 'prepares', 'committees', 'joint']
#
#
# Discourse_Atom 136
# ['guard', 'seashore', 'cemetery', 'treasure', 'guardsman', 'guardsmen', 'guards', 'instruments', 'coconino', 'origin', 'scenic', 'caregiving', 'treasures', 'arlington', 'disseminating', 'publisher', 'olson', 'disgrace', 'raza', 'americorps', 'trails', 'livable', 'childhelp', 'refuge', 'football']
#
#
# Discourse_Atom 137
# ['previous', 'dramatic', 'contrast', 'showing', 'preceding', 'fell', 'understate', 'gone', 'eroded', 'recent', 'trend', 'reductions', 'double', 'rough', 'signs', 'consecutive', 'slow', 'shows', 'phenomenon', 'economists', 'effect', 'alarming', 'poll', 'despite', 'paychecks']
#
#
# Discourse_Atom 138
# ['iraq', 'goes', 'gotten', 'imagine', 'tired', 'expect', 'squandered', 'excuses', 'skip', 'sadly', 'gone', 'acknowledge', 'independents', 'accept', 'touch', 'puts', 'shameful', 'mirrors', 'lied', 'happened', 'assumes', 'maybe', 'stopped', 'bit', 'convince']
#
#
# Discourse_Atom 139
# ['warming', 'marketplace', 'global', 'globalization', 'demands', 'cheaply', 'strongest', 'increasingly', 'planet', 'changing', 'effects', 'hinges', 'challenge', 'confront', 'faces', 'creativity', 'worlds', 'globalized', 'prosperity', 'impacts', 'compete', 'dynamic', 'profound', 'dominate', 'negative']
#
#
# Discourse_Atom 140
# ['convicted', 'offenses', 'aliens', 'criminal', 'h', 'applicants', 'numerical', 'removal', 'o', 'visa', 'status', 'requirement', 'fines', '5a', 'cards', 'fraud', 'penalties', 'voter', 'illegal', 'identity', '1b', 'applications', 'filed', 'visas', 'apply']
#
#
# Discourse_Atom 141
# ['relating', 'fbi', 'analysis', 'conducted', 'communications', 'document', 'documents', 'agency', 'records', 'concerning', 'appendix', 'investigations', 'cdc', 'investigation', 'director', 'reports', 'conduct', 'publicly', 'shall', 'referring', 'official', 'entity', 'obtained', 'bureau', 'requests']
#
#
# Discourse_Atom 142
# ['moving', 'step', 'moves', 'advance', 'recognizes', 'bold', 'closer', 'forward', 'represents', 'progress', 'hopeful', 'goals', 'goal', 'continued', 'crucial', 'achieving', 'todays', 'strong', 'important', 'importance', 'continuing', 'achieve', 'success', 'commitment', 'deserves']
#
#
# Discourse_Atom 143
# ['wage', 'prevailing', 'minimum', 'wages', 'raising', 'hour', 'tipped', 'adverse', 'supervisory', 'homestead', 'unions', 'guestworkers', 'waiters', 'salaries', 'effect', 'waitresses', 'tips', 'lowest', 'farther', 'unfair', 'raise', 'hourly', 'bacon', 'exempted', 'lilly']
#
#
# Discourse_Atom 144
# ['action', 'release', 'change', 'immediate', 'captives', 'plaguing', 'relatives', 'abatement', 'selma', 'press', 'day', 'class', 'triggering', 'crime', 'taken', 'anniversary', 'desegregation', 'facto', 'medals', 'parks', 'circuits', 'violent', 'milena', 'death', 'nationality']
#
#
# Discourse_Atom 145
# ['stem', 'cell', 'cells', 'research', 'cures', 'lifesaving', 'phones', 'embryos', 'treatments', 'cure', 'diseases', 'breakthroughs', 'cancer', 'embryonic', 'patients', 'disease', 'researchers', 'vaccines', 'life', 'extracted', 'fetuses', 'saving', 'breakthrough', 'curing', 'promising']
#
#
# Discourse_Atom 146
# ['negotiations', 'democratic', 'agreement', 'parties', 'cooperation', 'governors', 'arab', 'overwhelming', 'majority', 'qatar', 'leader', 'vast', 'representatives', 'consensus', 'treaty', 'iran', 'countries', 'concessions', 'alike', 'summit', 'groups', 'compromise', 'foreign', 'opposition', 'leaders']
#
#
# Discourse_Atom 147
# ['isakson', 'signers', 'sponsored', 'kennedys', 'hatch', 'craig', 'dorgan', 'gregg', 'dodd', 'snowe', 'martinez', 'walsh', 'santorum', 'harkin', 'domenici', 'cornyn', 'lott', 'dewine', 'smith', 'grassley', 'cosponsor', 'mikulski', 'sessions', 'graham', 'sanders']
#
#
# Discourse_Atom 148
# ['yesterday', 'late', 'summit', 'june', 'floor', 'children', 'united', 'expected', 'friedman', 'patsy', 'recently', 'february', 'unhcr', 'liheap', 'unspent', 'dni', 'speech', 'monday', 'wednesday', 'december', 'announcement', 'fy2007', 'resolution', 'tuesday', 'leader']
#
#
# Discourse_Atom 149
# ['reviewing', 'decisions', 'careful', 'transparent', 'judgments', 'review', 'particular', 'examination', 'objective', 'conduct', 'thorough', 'settlement', 'evidence', 'impartiality', 'deciding', 'relevant', 'obvious', 'interference', 'trial', 'remedy', 'proceedings', 'subpoenas', 'recuse', 'wiretap', 'scrutiny']

# %%
# for a specific atom, e.g., 112th atom look at 25 most similar words:
w2v.wv.similar_by_vector(dictionary[112],topn=25)
# Out:
# [('funds', 0.7516657114028931),
#  ('funding', 0.6887559294700623),
#  ('resources', 0.6219789385795593),
#  ('assistance', 0.6081899404525757),
#  ('efforts', 0.575427770614624),
#  ('reimbursements', 0.5240765810012817),
#  ('effort', 0.5111767053604126),
#  ('communities', 0.5077028274536133),
#  ('desperately', 0.5070760250091553),
#  ('responders', 0.5020491480827332),
#  ('match', 0.49038416147232056),
#  ('deliver', 0.4859146773815155),
#  ('grants', 0.4784278869628906),
#  ('declaration', 0.47553300857543945),
#  ('commonsense', 0.47147828340530396),
#  ('governments', 0.4701017439365387),
#  ('support', 0.4608587920665741),
#  ('programs', 0.4598115384578705),
#  ('rebuild', 0.4564478099346161),
#  ('flexibility', 0.4534948468208313),
#  ('initiative', 0.4531988799571991),
#  ('gear', 0.45291605591773987),
#  ('firefighting', 0.45242419838905334),
#  ('agencies', 0.45125699043273926),
#  ('evacuees', 0.4423292577266693)]

# %%
#useful relevant code:
w2v.wv.index_to_key[3452]
# Out:
# 'balances'

# %%
w2v.wv.most_similar('divorced', topn=15)
# Out:
# [('pregnant', 0.8717613816261292),
#  ('married', 0.8586174845695496),
#  ('disproportionately', 0.8537034392356873),
#  ('color', 0.839481770992279),
#  ('minorities', 0.8368760347366333),
#  ('sore', 0.8331732153892517),
#  ('couples', 0.8202372193336487),
#  ('babies', 0.8103613257408142),
#  ('ages', 0.7914664149284363),
#  ('shouldered', 0.788785994052887),
#  ('everyday', 0.7813878655433655),
#  ('aged', 0.7813552021980286),
#  ('caregivers', 0.7750584483146667),
#  ('spouse', 0.770943820476532),
#  ('bankrupt', 0.7709380984306335)]

# %%
np.where(alpha[w2v.wv.key_to_index['divorced']] != 0) #get index where the loading of a word onto discourse atoms is not 0
# Out:
# (array([ 22,  37, 105, 110, 134]),)
